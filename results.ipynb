# %%
import pandas as pd

# %%
ari_pre = pd.read_excel(r'1. ARIMAX\ARIMAX_results_pre.xlsx')
ari_post = pd.read_excel(r'1. ARIMAX\ARIMAX_results_post.xlsx')

# %%
proph_pre = pd.read_excel(r'2. Prophet\Prophet_results_pre.xlsx')
proph_post = pd.read_excel(r'2. Prophet\Prophet_results_post.xlsx')

# %%
xgb_pre = pd.read_excel(r'3. XGBoost\XGBoost_results_pre.xlsx')
xgb_post = pd.read_excel(r'3. XGBoost\XGBoost_results_post.xlsx')

# %%
rf_pre = pd.read_excel(r'4. Random Forrest\RandomForrest_results_pre.xlsx')
rf_post = pd.read_excel(r'4. Random Forrest\RandomForrest_results_post.xlsx')

# %%
et_pre = pd.read_excel(r'5. Extra Trees\ExtraTrees_results_pre.xlsx')
et_post = pd.read_excel(r'5. Extra Trees\ExtraTrees_results_post.xlsx')

# %%
lstm_pre = pd.read_excel(r'6. LSTM\LSTM_results_pre.xlsx')
lstm_post = pd.read_excel(r'6. LSTM\LSTM_results_post.xlsx')

# %%
mlp_pre = pd.read_excel(r'7. MLP\MLP_results_pre.xlsx')
mlp_post = pd.read_excel(r'7. MLP\MLP_results_post.xlsx')

# %%
dnn_pre = pd.read_excel(r'8. DNN\DNN_results_pre.xlsx')
dnn_post = pd.read_excel(r'8. DNN\DNN_results_post.xlsx')

# %%
gru_pre = pd.read_excel(r'9. GRU\GRU_results_pre.xlsx')
gru_post = pd.read_excel(r'9. GRU\GRU_results_post.xlsx')

# %%
companies = ['PKO', 'PZU', 'PGE', 'KGH', 'PKN', 'LLP', 'PEO', 'CDR', 'ENE', 'TPE',
            'AMC', 'CCC', 'BDX', 'CPS', 'ALR', 'JSW', 'ACP', 'CAR', 'SPL', 'PEP',
            'KRU', 'NEU', 'ERB', 'ATD', 'DAT', 'ZMT', 'KTY', 'ABE', 'MRB', 'UNI',
            'WIG', 'WIG20', 'mWIG40', 'sWIG80']

# %%
companies_large = ['PKO', 'PZU', 'PGE', 'KGH', 'PKN', 'LLP', 'PEO', 'CDR', 'ENE', 'TPE']
companies_mid = ['AMC', 'CCC', 'BDX', 'CPS', 'ALR', 'JSW', 'ACP', 'CAR', 'SPL', 'PEP']
companies_small = ['KRU', 'NEU', 'ERB', 'ATD', 'DAT', 'ZMT', 'KTY', 'ABE', 'MRB', 'UNI']
indices = ['WIG', 'WIG20', 'mWIG40', 'sWIG80']

# %% [markdown]
# # ARIMAX

# %%
ari_pre_hr = pd.DataFrame()
ari_pre_mda = pd.DataFrame()
ari_pre_mape = pd.DataFrame()

ari_post_hr = pd.DataFrame()
ari_post_mda = pd.DataFrame()
ari_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(ari_pre[ari_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    ari_pre_hr = pd.concat([ari_pre_hr, best])

    best = pd.DataFrame(ari_pre[ari_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    ari_pre_mda = pd.concat([ari_pre_mda, best])

    best = pd.DataFrame(ari_pre[ari_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    ari_pre_mape = pd.concat([ari_pre_mape, best])


    #post covid
    best = pd.DataFrame(ari_post[ari_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    ari_post_hr = pd.concat([ari_post_hr, best])

    best = pd.DataFrame(ari_post[ari_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    ari_post_mda = pd.concat([ari_post_mda, best])

    best = pd.DataFrame(ari_post[ari_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    ari_post_mape = pd.concat([ari_post_mape, best])

# %%
ari_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_pre_mda_averages.iloc[0,0] = ari_pre_mda['mape'].mean()
ari_pre_mda_averages.iloc[1,0] = ari_pre_mda[ari_pre_mda['company'].isin(companies_large)]['mape'].mean()
ari_pre_mda_averages.iloc[2,0] = ari_pre_mda[ari_pre_mda['company'].isin(companies_mid)]['mape'].mean()
ari_pre_mda_averages.iloc[3,0] = ari_pre_mda[ari_pre_mda['company'].isin(companies_small)]['mape'].mean()
ari_pre_mda_averages.iloc[4,0] = ari_pre_mda[ari_pre_mda['company'].isin(indices)]['mape'].mean()

ari_pre_mda_averages.iloc[0,1] = ari_pre_mda['mda'].mean()
ari_pre_mda_averages.iloc[1,1] = ari_pre_mda[ari_pre_mda['company'].isin(companies_large)]['mda'].mean()
ari_pre_mda_averages.iloc[2,1] = ari_pre_mda[ari_pre_mda['company'].isin(companies_mid)]['mda'].mean()
ari_pre_mda_averages.iloc[3,1] = ari_pre_mda[ari_pre_mda['company'].isin(companies_small)]['mda'].mean()
ari_pre_mda_averages.iloc[4,1] = ari_pre_mda[ari_pre_mda['company'].isin(indices)]['mda'].mean()

ari_pre_mda_averages.iloc[0,2] = ari_pre_mda['hr'].mean()
ari_pre_mda_averages.iloc[1,2] = ari_pre_mda[ari_pre_mda['company'].isin(companies_large)]['hr'].mean()
ari_pre_mda_averages.iloc[2,2] = ari_pre_mda[ari_pre_mda['company'].isin(companies_mid)]['hr'].mean()
ari_pre_mda_averages.iloc[3,2] = ari_pre_mda[ari_pre_mda['company'].isin(companies_small)]['hr'].mean()
ari_pre_mda_averages.iloc[4,2] = ari_pre_mda[ari_pre_mda['company'].isin(indices)]['hr'].mean()





ari_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_pre_mape_averages.iloc[0,0] = ari_pre_mape['mape'].mean()
ari_pre_mape_averages.iloc[1,0] = ari_pre_mape[ari_pre_mape['company'].isin(companies_large)]['mape'].mean()
ari_pre_mape_averages.iloc[2,0] = ari_pre_mape[ari_pre_mape['company'].isin(companies_mid)]['mape'].mean()
ari_pre_mape_averages.iloc[3,0] = ari_pre_mape[ari_pre_mape['company'].isin(companies_small)]['mape'].mean()
ari_pre_mape_averages.iloc[4,0] = ari_pre_mape[ari_pre_mape['company'].isin(indices)]['mape'].mean()

ari_pre_mape_averages.iloc[0,1] = ari_pre_mape['mda'].mean()
ari_pre_mape_averages.iloc[1,1] = ari_pre_mape[ari_pre_mape['company'].isin(companies_large)]['mda'].mean()
ari_pre_mape_averages.iloc[2,1] = ari_pre_mape[ari_pre_mape['company'].isin(companies_mid)]['mda'].mean()
ari_pre_mape_averages.iloc[3,1] = ari_pre_mape[ari_pre_mape['company'].isin(companies_small)]['mda'].mean()
ari_pre_mape_averages.iloc[4,1] = ari_pre_mape[ari_pre_mape['company'].isin(indices)]['mda'].mean()

ari_pre_mape_averages.iloc[0,2] = ari_pre_mape['hr'].mean()
ari_pre_mape_averages.iloc[1,2] = ari_pre_mape[ari_pre_mape['company'].isin(companies_large)]['hr'].mean()
ari_pre_mape_averages.iloc[2,2] = ari_pre_mape[ari_pre_mape['company'].isin(companies_mid)]['hr'].mean()
ari_pre_mape_averages.iloc[3,2] = ari_pre_mape[ari_pre_mape['company'].isin(companies_small)]['hr'].mean()
ari_pre_mape_averages.iloc[4,2] = ari_pre_mape[ari_pre_mape['company'].isin(indices)]['hr'].mean()




ari_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_pre_hr_averages.iloc[0,0] = ari_pre_hr['mape'].mean()
ari_pre_hr_averages.iloc[1,0] = ari_pre_hr[ari_pre_hr['company'].isin(companies_large)]['mape'].mean()
ari_pre_hr_averages.iloc[2,0] = ari_pre_hr[ari_pre_hr['company'].isin(companies_mid)]['mape'].mean()
ari_pre_hr_averages.iloc[3,0] = ari_pre_hr[ari_pre_hr['company'].isin(companies_small)]['mape'].mean()
ari_pre_hr_averages.iloc[4,0] = ari_pre_hr[ari_pre_hr['company'].isin(indices)]['mape'].mean()

ari_pre_hr_averages.iloc[0,1] = ari_pre_hr['mda'].mean()
ari_pre_hr_averages.iloc[1,1] = ari_pre_hr[ari_pre_hr['company'].isin(companies_large)]['mda'].mean()
ari_pre_hr_averages.iloc[2,1] = ari_pre_hr[ari_pre_hr['company'].isin(companies_mid)]['mda'].mean()
ari_pre_hr_averages.iloc[3,1] = ari_pre_hr[ari_pre_hr['company'].isin(companies_small)]['mda'].mean()
ari_pre_hr_averages.iloc[4,1] = ari_pre_hr[ari_pre_hr['company'].isin(indices)]['mda'].mean()

ari_pre_hr_averages.iloc[0,2] = ari_pre_hr['hr'].mean()
ari_pre_hr_averages.iloc[1,2] = ari_pre_hr[ari_pre_hr['company'].isin(companies_large)]['hr'].mean()
ari_pre_hr_averages.iloc[2,2] = ari_pre_hr[ari_pre_hr['company'].isin(companies_mid)]['hr'].mean()
ari_pre_hr_averages.iloc[3,2] = ari_pre_hr[ari_pre_hr['company'].isin(companies_small)]['hr'].mean()
ari_pre_hr_averages.iloc[4,2] = ari_pre_hr[ari_pre_hr['company'].isin(indices)]['hr'].mean()



ari_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_post_mda_averages.iloc[0,0] = ari_post_mda['mape'].mean()
ari_post_mda_averages.iloc[1,0] = ari_post_mda[ari_post_mda['company'].isin(companies_large)]['mape'].mean()
ari_post_mda_averages.iloc[2,0] = ari_post_mda[ari_post_mda['company'].isin(companies_mid)]['mape'].mean()
ari_post_mda_averages.iloc[3,0] = ari_post_mda[ari_post_mda['company'].isin(companies_small)]['mape'].mean()
ari_post_mda_averages.iloc[4,0] = ari_post_mda[ari_post_mda['company'].isin(indices)]['mape'].mean()

ari_post_mda_averages.iloc[0,1] = ari_post_mda['mda'].mean()
ari_post_mda_averages.iloc[1,1] = ari_post_mda[ari_post_mda['company'].isin(companies_large)]['mda'].mean()
ari_post_mda_averages.iloc[2,1] = ari_post_mda[ari_post_mda['company'].isin(companies_mid)]['mda'].mean()
ari_post_mda_averages.iloc[3,1] = ari_post_mda[ari_post_mda['company'].isin(companies_small)]['mda'].mean()
ari_post_mda_averages.iloc[4,1] = ari_post_mda[ari_post_mda['company'].isin(indices)]['mda'].mean()

ari_post_mda_averages.iloc[0,2] = ari_post_mda['hr'].mean()
ari_post_mda_averages.iloc[1,2] = ari_post_mda[ari_post_mda['company'].isin(companies_large)]['hr'].mean()
ari_post_mda_averages.iloc[2,2] = ari_post_mda[ari_post_mda['company'].isin(companies_mid)]['hr'].mean()
ari_post_mda_averages.iloc[3,2] = ari_post_mda[ari_post_mda['company'].isin(companies_small)]['hr'].mean()
ari_post_mda_averages.iloc[4,2] = ari_post_mda[ari_post_mda['company'].isin(indices)]['hr'].mean()





ari_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_post_mape_averages.iloc[0,0] = ari_post_mape['mape'].mean()
ari_post_mape_averages.iloc[1,0] = ari_post_mape[ari_post_mape['company'].isin(companies_large)]['mape'].mean()
ari_post_mape_averages.iloc[2,0] = ari_post_mape[ari_post_mape['company'].isin(companies_mid)]['mape'].mean()
ari_post_mape_averages.iloc[3,0] = ari_post_mape[ari_post_mape['company'].isin(companies_small)]['mape'].mean()
ari_post_mape_averages.iloc[4,0] = ari_post_mape[ari_post_mape['company'].isin(indices)]['mape'].mean()

ari_post_mape_averages.iloc[0,1] = ari_post_mape['mda'].mean()
ari_post_mape_averages.iloc[1,1] = ari_post_mape[ari_post_mape['company'].isin(companies_large)]['mda'].mean()
ari_post_mape_averages.iloc[2,1] = ari_post_mape[ari_post_mape['company'].isin(companies_mid)]['mda'].mean()
ari_post_mape_averages.iloc[3,1] = ari_post_mape[ari_post_mape['company'].isin(companies_small)]['mda'].mean()
ari_post_mape_averages.iloc[4,1] = ari_post_mape[ari_post_mape['company'].isin(indices)]['mda'].mean()

ari_post_mape_averages.iloc[0,2] = ari_post_mape['hr'].mean()
ari_post_mape_averages.iloc[1,2] = ari_post_mape[ari_post_mape['company'].isin(companies_large)]['hr'].mean()
ari_post_mape_averages.iloc[2,2] = ari_post_mape[ari_post_mape['company'].isin(companies_mid)]['hr'].mean()
ari_post_mape_averages.iloc[3,2] = ari_post_mape[ari_post_mape['company'].isin(companies_small)]['hr'].mean()
ari_post_mape_averages.iloc[4,2] = ari_post_mape[ari_post_mape['company'].isin(indices)]['hr'].mean()




ari_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

ari_post_hr_averages.iloc[0,0] = ari_post_hr['mape'].mean()
ari_post_hr_averages.iloc[1,0] = ari_post_hr[ari_post_hr['company'].isin(companies_large)]['mape'].mean()
ari_post_hr_averages.iloc[2,0] = ari_post_hr[ari_post_hr['company'].isin(companies_mid)]['mape'].mean()
ari_post_hr_averages.iloc[3,0] = ari_post_hr[ari_post_hr['company'].isin(companies_small)]['mape'].mean()
ari_post_hr_averages.iloc[4,0] = ari_post_hr[ari_post_hr['company'].isin(indices)]['mape'].mean()

ari_post_hr_averages.iloc[0,1] = ari_post_hr['mda'].mean()
ari_post_hr_averages.iloc[1,1] = ari_post_hr[ari_post_hr['company'].isin(companies_large)]['mda'].mean()
ari_post_hr_averages.iloc[2,1] = ari_post_hr[ari_post_hr['company'].isin(companies_mid)]['mda'].mean()
ari_post_hr_averages.iloc[3,1] = ari_post_hr[ari_post_hr['company'].isin(companies_small)]['mda'].mean()
ari_post_hr_averages.iloc[4,1] = ari_post_hr[ari_post_hr['company'].isin(indices)]['mda'].mean()

ari_post_hr_averages.iloc[0,2] = ari_post_hr['hr'].mean()
ari_post_hr_averages.iloc[1,2] = ari_post_hr[ari_post_hr['company'].isin(companies_large)]['hr'].mean()
ari_post_hr_averages.iloc[2,2] = ari_post_hr[ari_post_hr['company'].isin(companies_mid)]['hr'].mean()
ari_post_hr_averages.iloc[3,2] = ari_post_hr[ari_post_hr['company'].isin(companies_small)]['hr'].mean()
ari_post_hr_averages.iloc[4,2] = ari_post_hr[ari_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # Prophet

# %%
proph_pre_hr = pd.DataFrame()
proph_pre_mda = pd.DataFrame()
proph_pre_mape = pd.DataFrame()

proph_post_hr = pd.DataFrame()
proph_post_mda = pd.DataFrame()
proph_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(proph_pre[proph_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    proph_pre_hr = pd.concat([proph_pre_hr, best])

    best = pd.DataFrame(proph_pre[proph_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    proph_pre_mda = pd.concat([proph_pre_mda, best])

    best = pd.DataFrame(proph_pre[proph_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    proph_pre_mape = pd.concat([proph_pre_mape, best])


    #post covid
    best = pd.DataFrame(proph_post[proph_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    proph_post_hr = pd.concat([proph_post_hr, best])

    best = pd.DataFrame(proph_post[proph_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    proph_post_mda = pd.concat([proph_post_mda, best])

    best = pd.DataFrame(proph_post[proph_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    proph_post_mape = pd.concat([proph_post_mape, best])

# %%
proph_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_pre_mda_averages.iloc[0,0] = proph_pre_mda['mape'].mean()
proph_pre_mda_averages.iloc[1,0] = proph_pre_mda[proph_pre_mda['company'].isin(companies_large)]['mape'].mean()
proph_pre_mda_averages.iloc[2,0] = proph_pre_mda[proph_pre_mda['company'].isin(companies_mid)]['mape'].mean()
proph_pre_mda_averages.iloc[3,0] = proph_pre_mda[proph_pre_mda['company'].isin(companies_small)]['mape'].mean()
proph_pre_mda_averages.iloc[4,0] = proph_pre_mda[proph_pre_mda['company'].isin(indices)]['mape'].mean()

proph_pre_mda_averages.iloc[0,1] = proph_pre_mda['mda'].mean()
proph_pre_mda_averages.iloc[1,1] = proph_pre_mda[proph_pre_mda['company'].isin(companies_large)]['mda'].mean()
proph_pre_mda_averages.iloc[2,1] = proph_pre_mda[proph_pre_mda['company'].isin(companies_mid)]['mda'].mean()
proph_pre_mda_averages.iloc[3,1] = proph_pre_mda[proph_pre_mda['company'].isin(companies_small)]['mda'].mean()
proph_pre_mda_averages.iloc[4,1] = proph_pre_mda[proph_pre_mda['company'].isin(indices)]['mda'].mean()

proph_pre_mda_averages.iloc[0,2] = proph_pre_mda['hr'].mean()
proph_pre_mda_averages.iloc[1,2] = proph_pre_mda[proph_pre_mda['company'].isin(companies_large)]['hr'].mean()
proph_pre_mda_averages.iloc[2,2] = proph_pre_mda[proph_pre_mda['company'].isin(companies_mid)]['hr'].mean()
proph_pre_mda_averages.iloc[3,2] = proph_pre_mda[proph_pre_mda['company'].isin(companies_small)]['hr'].mean()
proph_pre_mda_averages.iloc[4,2] = proph_pre_mda[proph_pre_mda['company'].isin(indices)]['hr'].mean()





proph_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_pre_mape_averages.iloc[0,0] = proph_pre_mape['mape'].mean()
proph_pre_mape_averages.iloc[1,0] = proph_pre_mape[proph_pre_mape['company'].isin(companies_large)]['mape'].mean()
proph_pre_mape_averages.iloc[2,0] = proph_pre_mape[proph_pre_mape['company'].isin(companies_mid)]['mape'].mean()
proph_pre_mape_averages.iloc[3,0] = proph_pre_mape[proph_pre_mape['company'].isin(companies_small)]['mape'].mean()
proph_pre_mape_averages.iloc[4,0] = proph_pre_mape[proph_pre_mape['company'].isin(indices)]['mape'].mean()

proph_pre_mape_averages.iloc[0,1] = proph_pre_mape['mda'].mean()
proph_pre_mape_averages.iloc[1,1] = proph_pre_mape[proph_pre_mape['company'].isin(companies_large)]['mda'].mean()
proph_pre_mape_averages.iloc[2,1] = proph_pre_mape[proph_pre_mape['company'].isin(companies_mid)]['mda'].mean()
proph_pre_mape_averages.iloc[3,1] = proph_pre_mape[proph_pre_mape['company'].isin(companies_small)]['mda'].mean()
proph_pre_mape_averages.iloc[4,1] = proph_pre_mape[proph_pre_mape['company'].isin(indices)]['mda'].mean()

proph_pre_mape_averages.iloc[0,2] = proph_pre_mape['hr'].mean()
proph_pre_mape_averages.iloc[1,2] = proph_pre_mape[proph_pre_mape['company'].isin(companies_large)]['hr'].mean()
proph_pre_mape_averages.iloc[2,2] = proph_pre_mape[proph_pre_mape['company'].isin(companies_mid)]['hr'].mean()
proph_pre_mape_averages.iloc[3,2] = proph_pre_mape[proph_pre_mape['company'].isin(companies_small)]['hr'].mean()
proph_pre_mape_averages.iloc[4,2] = proph_pre_mape[proph_pre_mape['company'].isin(indices)]['hr'].mean()




proph_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_pre_hr_averages.iloc[0,0] = proph_pre_hr['mape'].mean()
proph_pre_hr_averages.iloc[1,0] = proph_pre_hr[proph_pre_hr['company'].isin(companies_large)]['mape'].mean()
proph_pre_hr_averages.iloc[2,0] = proph_pre_hr[proph_pre_hr['company'].isin(companies_mid)]['mape'].mean()
proph_pre_hr_averages.iloc[3,0] = proph_pre_hr[proph_pre_hr['company'].isin(companies_small)]['mape'].mean()
proph_pre_hr_averages.iloc[4,0] = proph_pre_hr[proph_pre_hr['company'].isin(indices)]['mape'].mean()

proph_pre_hr_averages.iloc[0,1] = proph_pre_hr['mda'].mean()
proph_pre_hr_averages.iloc[1,1] = proph_pre_hr[proph_pre_hr['company'].isin(companies_large)]['mda'].mean()
proph_pre_hr_averages.iloc[2,1] = proph_pre_hr[proph_pre_hr['company'].isin(companies_mid)]['mda'].mean()
proph_pre_hr_averages.iloc[3,1] = proph_pre_hr[proph_pre_hr['company'].isin(companies_small)]['mda'].mean()
proph_pre_hr_averages.iloc[4,1] = proph_pre_hr[proph_pre_hr['company'].isin(indices)]['mda'].mean()

proph_pre_hr_averages.iloc[0,2] = proph_pre_hr['hr'].mean()
proph_pre_hr_averages.iloc[1,2] = proph_pre_hr[proph_pre_hr['company'].isin(companies_large)]['hr'].mean()
proph_pre_hr_averages.iloc[2,2] = proph_pre_hr[proph_pre_hr['company'].isin(companies_mid)]['hr'].mean()
proph_pre_hr_averages.iloc[3,2] = proph_pre_hr[proph_pre_hr['company'].isin(companies_small)]['hr'].mean()
proph_pre_hr_averages.iloc[4,2] = proph_pre_hr[proph_pre_hr['company'].isin(indices)]['hr'].mean()




proph_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_post_mda_averages.iloc[0,0] = proph_post_mda['mape'].mean()
proph_post_mda_averages.iloc[1,0] = proph_post_mda[proph_post_mda['company'].isin(companies_large)]['mape'].mean()
proph_post_mda_averages.iloc[2,0] = proph_post_mda[proph_post_mda['company'].isin(companies_mid)]['mape'].mean()
proph_post_mda_averages.iloc[3,0] = proph_post_mda[proph_post_mda['company'].isin(companies_small)]['mape'].mean()
proph_post_mda_averages.iloc[4,0] = proph_post_mda[proph_post_mda['company'].isin(indices)]['mape'].mean()

proph_post_mda_averages.iloc[0,1] = proph_post_mda['mda'].mean()
proph_post_mda_averages.iloc[1,1] = proph_post_mda[proph_post_mda['company'].isin(companies_large)]['mda'].mean()
proph_post_mda_averages.iloc[2,1] = proph_post_mda[proph_post_mda['company'].isin(companies_mid)]['mda'].mean()
proph_post_mda_averages.iloc[3,1] = proph_post_mda[proph_post_mda['company'].isin(companies_small)]['mda'].mean()
proph_post_mda_averages.iloc[4,1] = proph_post_mda[proph_post_mda['company'].isin(indices)]['mda'].mean()

proph_post_mda_averages.iloc[0,2] = proph_post_mda['hr'].mean()
proph_post_mda_averages.iloc[1,2] = proph_post_mda[proph_post_mda['company'].isin(companies_large)]['hr'].mean()
proph_post_mda_averages.iloc[2,2] = proph_post_mda[proph_post_mda['company'].isin(companies_mid)]['hr'].mean()
proph_post_mda_averages.iloc[3,2] = proph_post_mda[proph_post_mda['company'].isin(companies_small)]['hr'].mean()
proph_post_mda_averages.iloc[4,2] = proph_post_mda[proph_post_mda['company'].isin(indices)]['hr'].mean()





proph_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_post_mape_averages.iloc[0,0] = proph_post_mape['mape'].mean()
proph_post_mape_averages.iloc[1,0] = proph_post_mape[proph_post_mape['company'].isin(companies_large)]['mape'].mean()
proph_post_mape_averages.iloc[2,0] = proph_post_mape[proph_post_mape['company'].isin(companies_mid)]['mape'].mean()
proph_post_mape_averages.iloc[3,0] = proph_post_mape[proph_post_mape['company'].isin(companies_small)]['mape'].mean()
proph_post_mape_averages.iloc[4,0] = proph_post_mape[proph_post_mape['company'].isin(indices)]['mape'].mean()

proph_post_mape_averages.iloc[0,1] = proph_post_mape['mda'].mean()
proph_post_mape_averages.iloc[1,1] = proph_post_mape[proph_post_mape['company'].isin(companies_large)]['mda'].mean()
proph_post_mape_averages.iloc[2,1] = proph_post_mape[proph_post_mape['company'].isin(companies_mid)]['mda'].mean()
proph_post_mape_averages.iloc[3,1] = proph_post_mape[proph_post_mape['company'].isin(companies_small)]['mda'].mean()
proph_post_mape_averages.iloc[4,1] = proph_post_mape[proph_post_mape['company'].isin(indices)]['mda'].mean()

proph_post_mape_averages.iloc[0,2] = proph_post_mape['hr'].mean()
proph_post_mape_averages.iloc[1,2] = proph_post_mape[proph_post_mape['company'].isin(companies_large)]['hr'].mean()
proph_post_mape_averages.iloc[2,2] = proph_post_mape[proph_post_mape['company'].isin(companies_mid)]['hr'].mean()
proph_post_mape_averages.iloc[3,2] = proph_post_mape[proph_post_mape['company'].isin(companies_small)]['hr'].mean()
proph_post_mape_averages.iloc[4,2] = proph_post_mape[proph_post_mape['company'].isin(indices)]['hr'].mean()




proph_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

proph_post_hr_averages.iloc[0,0] = proph_post_hr['mape'].mean()
proph_post_hr_averages.iloc[1,0] = proph_post_hr[proph_post_hr['company'].isin(companies_large)]['mape'].mean()
proph_post_hr_averages.iloc[2,0] = proph_post_hr[proph_post_hr['company'].isin(companies_mid)]['mape'].mean()
proph_post_hr_averages.iloc[3,0] = proph_post_hr[proph_post_hr['company'].isin(companies_small)]['mape'].mean()
proph_post_hr_averages.iloc[4,0] = proph_post_hr[proph_post_hr['company'].isin(indices)]['mape'].mean()

proph_post_hr_averages.iloc[0,1] = proph_post_hr['mda'].mean()
proph_post_hr_averages.iloc[1,1] = proph_post_hr[proph_post_hr['company'].isin(companies_large)]['mda'].mean()
proph_post_hr_averages.iloc[2,1] = proph_post_hr[proph_post_hr['company'].isin(companies_mid)]['mda'].mean()
proph_post_hr_averages.iloc[3,1] = proph_post_hr[proph_post_hr['company'].isin(companies_small)]['mda'].mean()
proph_post_hr_averages.iloc[4,1] = proph_post_hr[proph_post_hr['company'].isin(indices)]['mda'].mean()

proph_post_hr_averages.iloc[0,2] = proph_post_hr['hr'].mean()
proph_post_hr_averages.iloc[1,2] = proph_post_hr[proph_post_hr['company'].isin(companies_large)]['hr'].mean()
proph_post_hr_averages.iloc[2,2] = proph_post_hr[proph_post_hr['company'].isin(companies_mid)]['hr'].mean()
proph_post_hr_averages.iloc[3,2] = proph_post_hr[proph_post_hr['company'].isin(companies_small)]['hr'].mean()
proph_post_hr_averages.iloc[4,2] = proph_post_hr[proph_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # XGBoost

# %%
xgb_pre_hr = pd.DataFrame()
xgb_pre_mda = pd.DataFrame()
xgb_pre_mape = pd.DataFrame()

xgb_post_hr = pd.DataFrame()
xgb_post_mda = pd.DataFrame()
xgb_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(xgb_pre[xgb_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    xgb_pre_hr = pd.concat([xgb_pre_hr, best])

    best = pd.DataFrame(xgb_pre[xgb_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    xgb_pre_mda = pd.concat([xgb_pre_mda, best])

    best = pd.DataFrame(xgb_pre[xgb_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    xgb_pre_mape = pd.concat([xgb_pre_mape, best])


    #post covid
    best = pd.DataFrame(xgb_post[xgb_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    xgb_post_hr = pd.concat([xgb_post_hr, best])

    best = pd.DataFrame(xgb_post[xgb_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    xgb_post_mda = pd.concat([xgb_post_mda, best])

    best = pd.DataFrame(xgb_post[xgb_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    xgb_post_mape = pd.concat([xgb_post_mape, best])

# %%
xgb_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_pre_mda_averages.iloc[0,0] = xgb_pre_mda['mape'].mean()
xgb_pre_mda_averages.iloc[1,0] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_large)]['mape'].mean()
xgb_pre_mda_averages.iloc[2,0] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_mid)]['mape'].mean()
xgb_pre_mda_averages.iloc[3,0] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_small)]['mape'].mean()
xgb_pre_mda_averages.iloc[4,0] = xgb_pre_mda[xgb_pre_mda['company'].isin(indices)]['mape'].mean()

xgb_pre_mda_averages.iloc[0,1] = xgb_pre_mda['mda'].mean()
xgb_pre_mda_averages.iloc[1,1] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_large)]['mda'].mean()
xgb_pre_mda_averages.iloc[2,1] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_mid)]['mda'].mean()
xgb_pre_mda_averages.iloc[3,1] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_small)]['mda'].mean()
xgb_pre_mda_averages.iloc[4,1] = xgb_pre_mda[xgb_pre_mda['company'].isin(indices)]['mda'].mean()

xgb_pre_mda_averages.iloc[0,2] = xgb_pre_mda['hr'].mean()
xgb_pre_mda_averages.iloc[1,2] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_large)]['hr'].mean()
xgb_pre_mda_averages.iloc[2,2] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_mid)]['hr'].mean()
xgb_pre_mda_averages.iloc[3,2] = xgb_pre_mda[xgb_pre_mda['company'].isin(companies_small)]['hr'].mean()
xgb_pre_mda_averages.iloc[4,2] = xgb_pre_mda[xgb_pre_mda['company'].isin(indices)]['hr'].mean()





xgb_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_pre_mape_averages.iloc[0,0] = xgb_pre_mape['mape'].mean()
xgb_pre_mape_averages.iloc[1,0] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_large)]['mape'].mean()
xgb_pre_mape_averages.iloc[2,0] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_mid)]['mape'].mean()
xgb_pre_mape_averages.iloc[3,0] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_small)]['mape'].mean()
xgb_pre_mape_averages.iloc[4,0] = xgb_pre_mape[xgb_pre_mape['company'].isin(indices)]['mape'].mean()

xgb_pre_mape_averages.iloc[0,1] = xgb_pre_mape['mda'].mean()
xgb_pre_mape_averages.iloc[1,1] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_large)]['mda'].mean()
xgb_pre_mape_averages.iloc[2,1] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_mid)]['mda'].mean()
xgb_pre_mape_averages.iloc[3,1] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_small)]['mda'].mean()
xgb_pre_mape_averages.iloc[4,1] = xgb_pre_mape[xgb_pre_mape['company'].isin(indices)]['mda'].mean()

xgb_pre_mape_averages.iloc[0,2] = xgb_pre_mape['hr'].mean()
xgb_pre_mape_averages.iloc[1,2] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_large)]['hr'].mean()
xgb_pre_mape_averages.iloc[2,2] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_mid)]['hr'].mean()
xgb_pre_mape_averages.iloc[3,2] = xgb_pre_mape[xgb_pre_mape['company'].isin(companies_small)]['hr'].mean()
xgb_pre_mape_averages.iloc[4,2] = xgb_pre_mape[xgb_pre_mape['company'].isin(indices)]['hr'].mean()




xgb_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_pre_hr_averages.iloc[0,0] = xgb_pre_hr['mape'].mean()
xgb_pre_hr_averages.iloc[1,0] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_large)]['mape'].mean()
xgb_pre_hr_averages.iloc[2,0] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_mid)]['mape'].mean()
xgb_pre_hr_averages.iloc[3,0] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_small)]['mape'].mean()
xgb_pre_hr_averages.iloc[4,0] = xgb_pre_hr[xgb_pre_hr['company'].isin(indices)]['mape'].mean()

xgb_pre_hr_averages.iloc[0,1] = xgb_pre_hr['mda'].mean()
xgb_pre_hr_averages.iloc[1,1] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_large)]['mda'].mean()
xgb_pre_hr_averages.iloc[2,1] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_mid)]['mda'].mean()
xgb_pre_hr_averages.iloc[3,1] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_small)]['mda'].mean()
xgb_pre_hr_averages.iloc[4,1] = xgb_pre_hr[xgb_pre_hr['company'].isin(indices)]['mda'].mean()

xgb_pre_hr_averages.iloc[0,2] = xgb_pre_hr['hr'].mean()
xgb_pre_hr_averages.iloc[1,2] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_large)]['hr'].mean()
xgb_pre_hr_averages.iloc[2,2] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_mid)]['hr'].mean()
xgb_pre_hr_averages.iloc[3,2] = xgb_pre_hr[xgb_pre_hr['company'].isin(companies_small)]['hr'].mean()
xgb_pre_hr_averages.iloc[4,2] = xgb_pre_hr[xgb_pre_hr['company'].isin(indices)]['hr'].mean()




xgb_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_post_mda_averages.iloc[0,0] = xgb_post_mda['mape'].mean()
xgb_post_mda_averages.iloc[1,0] = xgb_post_mda[xgb_post_mda['company'].isin(companies_large)]['mape'].mean()
xgb_post_mda_averages.iloc[2,0] = xgb_post_mda[xgb_post_mda['company'].isin(companies_mid)]['mape'].mean()
xgb_post_mda_averages.iloc[3,0] = xgb_post_mda[xgb_post_mda['company'].isin(companies_small)]['mape'].mean()
xgb_post_mda_averages.iloc[4,0] = xgb_post_mda[xgb_post_mda['company'].isin(indices)]['mape'].mean()

xgb_post_mda_averages.iloc[0,1] = xgb_post_mda['mda'].mean()
xgb_post_mda_averages.iloc[1,1] = xgb_post_mda[xgb_post_mda['company'].isin(companies_large)]['mda'].mean()
xgb_post_mda_averages.iloc[2,1] = xgb_post_mda[xgb_post_mda['company'].isin(companies_mid)]['mda'].mean()
xgb_post_mda_averages.iloc[3,1] = xgb_post_mda[xgb_post_mda['company'].isin(companies_small)]['mda'].mean()
xgb_post_mda_averages.iloc[4,1] = xgb_post_mda[xgb_post_mda['company'].isin(indices)]['mda'].mean()

xgb_post_mda_averages.iloc[0,2] = xgb_post_mda['hr'].mean()
xgb_post_mda_averages.iloc[1,2] = xgb_post_mda[xgb_post_mda['company'].isin(companies_large)]['hr'].mean()
xgb_post_mda_averages.iloc[2,2] = xgb_post_mda[xgb_post_mda['company'].isin(companies_mid)]['hr'].mean()
xgb_post_mda_averages.iloc[3,2] = xgb_post_mda[xgb_post_mda['company'].isin(companies_small)]['hr'].mean()
xgb_post_mda_averages.iloc[4,2] = xgb_post_mda[xgb_post_mda['company'].isin(indices)]['hr'].mean()





xgb_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_post_mape_averages.iloc[0,0] = xgb_post_mape['mape'].mean()
xgb_post_mape_averages.iloc[1,0] = xgb_post_mape[xgb_post_mape['company'].isin(companies_large)]['mape'].mean()
xgb_post_mape_averages.iloc[2,0] = xgb_post_mape[xgb_post_mape['company'].isin(companies_mid)]['mape'].mean()
xgb_post_mape_averages.iloc[3,0] = xgb_post_mape[xgb_post_mape['company'].isin(companies_small)]['mape'].mean()
xgb_post_mape_averages.iloc[4,0] = xgb_post_mape[xgb_post_mape['company'].isin(indices)]['mape'].mean()

xgb_post_mape_averages.iloc[0,1] = xgb_post_mape['mda'].mean()
xgb_post_mape_averages.iloc[1,1] = xgb_post_mape[xgb_post_mape['company'].isin(companies_large)]['mda'].mean()
xgb_post_mape_averages.iloc[2,1] = xgb_post_mape[xgb_post_mape['company'].isin(companies_mid)]['mda'].mean()
xgb_post_mape_averages.iloc[3,1] = xgb_post_mape[xgb_post_mape['company'].isin(companies_small)]['mda'].mean()
xgb_post_mape_averages.iloc[4,1] = xgb_post_mape[xgb_post_mape['company'].isin(indices)]['mda'].mean()

xgb_post_mape_averages.iloc[0,2] = xgb_post_mape['hr'].mean()
xgb_post_mape_averages.iloc[1,2] = xgb_post_mape[xgb_post_mape['company'].isin(companies_large)]['hr'].mean()
xgb_post_mape_averages.iloc[2,2] = xgb_post_mape[xgb_post_mape['company'].isin(companies_mid)]['hr'].mean()
xgb_post_mape_averages.iloc[3,2] = xgb_post_mape[xgb_post_mape['company'].isin(companies_small)]['hr'].mean()
xgb_post_mape_averages.iloc[4,2] = xgb_post_mape[xgb_post_mape['company'].isin(indices)]['hr'].mean()




xgb_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

xgb_post_hr_averages.iloc[0,0] = xgb_post_hr['mape'].mean()
xgb_post_hr_averages.iloc[1,0] = xgb_post_hr[xgb_post_hr['company'].isin(companies_large)]['mape'].mean()
xgb_post_hr_averages.iloc[2,0] = xgb_post_hr[xgb_post_hr['company'].isin(companies_mid)]['mape'].mean()
xgb_post_hr_averages.iloc[3,0] = xgb_post_hr[xgb_post_hr['company'].isin(companies_small)]['mape'].mean()
xgb_post_hr_averages.iloc[4,0] = xgb_post_hr[xgb_post_hr['company'].isin(indices)]['mape'].mean()

xgb_post_hr_averages.iloc[0,1] = xgb_post_hr['mda'].mean()
xgb_post_hr_averages.iloc[1,1] = xgb_post_hr[xgb_post_hr['company'].isin(companies_large)]['mda'].mean()
xgb_post_hr_averages.iloc[2,1] = xgb_post_hr[xgb_post_hr['company'].isin(companies_mid)]['mda'].mean()
xgb_post_hr_averages.iloc[3,1] = xgb_post_hr[xgb_post_hr['company'].isin(companies_small)]['mda'].mean()
xgb_post_hr_averages.iloc[4,1] = xgb_post_hr[xgb_post_hr['company'].isin(indices)]['mda'].mean()

xgb_post_hr_averages.iloc[0,2] = xgb_post_hr['hr'].mean()
xgb_post_hr_averages.iloc[1,2] = xgb_post_hr[xgb_post_hr['company'].isin(companies_large)]['hr'].mean()
xgb_post_hr_averages.iloc[2,2] = xgb_post_hr[xgb_post_hr['company'].isin(companies_mid)]['hr'].mean()
xgb_post_hr_averages.iloc[3,2] = xgb_post_hr[xgb_post_hr['company'].isin(companies_small)]['hr'].mean()
xgb_post_hr_averages.iloc[4,2] = xgb_post_hr[xgb_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # Random Forrest

# %%
rf_pre_hr = pd.DataFrame()
rf_pre_mda = pd.DataFrame()
rf_pre_mape = pd.DataFrame()

rf_post_hr = pd.DataFrame()
rf_post_mda = pd.DataFrame()
rf_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(rf_pre[rf_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    rf_pre_hr = pd.concat([rf_pre_hr, best])

    best = pd.DataFrame(rf_pre[rf_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    rf_pre_mda = pd.concat([rf_pre_mda, best])

    best = pd.DataFrame(rf_pre[rf_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    rf_pre_mape = pd.concat([rf_pre_mape, best])


    #post covid
    best = pd.DataFrame(rf_post[rf_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    rf_post_hr = pd.concat([rf_post_hr, best])

    best = pd.DataFrame(rf_post[rf_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    rf_post_mda = pd.concat([rf_post_mda, best])

    best = pd.DataFrame(rf_post[rf_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    rf_post_mape = pd.concat([rf_post_mape, best])

# %%
rf_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_pre_mda_averages.iloc[0,0] = rf_pre_mda['mape'].mean()
rf_pre_mda_averages.iloc[1,0] = rf_pre_mda[rf_pre_mda['company'].isin(companies_large)]['mape'].mean()
rf_pre_mda_averages.iloc[2,0] = rf_pre_mda[rf_pre_mda['company'].isin(companies_mid)]['mape'].mean()
rf_pre_mda_averages.iloc[3,0] = rf_pre_mda[rf_pre_mda['company'].isin(companies_small)]['mape'].mean()
rf_pre_mda_averages.iloc[4,0] = rf_pre_mda[rf_pre_mda['company'].isin(indices)]['mape'].mean()

rf_pre_mda_averages.iloc[0,1] = rf_pre_mda['mda'].mean()
rf_pre_mda_averages.iloc[1,1] = rf_pre_mda[rf_pre_mda['company'].isin(companies_large)]['mda'].mean()
rf_pre_mda_averages.iloc[2,1] = rf_pre_mda[rf_pre_mda['company'].isin(companies_mid)]['mda'].mean()
rf_pre_mda_averages.iloc[3,1] = rf_pre_mda[rf_pre_mda['company'].isin(companies_small)]['mda'].mean()
rf_pre_mda_averages.iloc[4,1] = rf_pre_mda[rf_pre_mda['company'].isin(indices)]['mda'].mean()

rf_pre_mda_averages.iloc[0,2] = rf_pre_mda['hr'].mean()
rf_pre_mda_averages.iloc[1,2] = rf_pre_mda[rf_pre_mda['company'].isin(companies_large)]['hr'].mean()
rf_pre_mda_averages.iloc[2,2] = rf_pre_mda[rf_pre_mda['company'].isin(companies_mid)]['hr'].mean()
rf_pre_mda_averages.iloc[3,2] = rf_pre_mda[rf_pre_mda['company'].isin(companies_small)]['hr'].mean()
rf_pre_mda_averages.iloc[4,2] = rf_pre_mda[rf_pre_mda['company'].isin(indices)]['hr'].mean()





rf_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_pre_mape_averages.iloc[0,0] = rf_pre_mape['mape'].mean()
rf_pre_mape_averages.iloc[1,0] = rf_pre_mape[rf_pre_mape['company'].isin(companies_large)]['mape'].mean()
rf_pre_mape_averages.iloc[2,0] = rf_pre_mape[rf_pre_mape['company'].isin(companies_mid)]['mape'].mean()
rf_pre_mape_averages.iloc[3,0] = rf_pre_mape[rf_pre_mape['company'].isin(companies_small)]['mape'].mean()
rf_pre_mape_averages.iloc[4,0] = rf_pre_mape[rf_pre_mape['company'].isin(indices)]['mape'].mean()

rf_pre_mape_averages.iloc[0,1] = rf_pre_mape['mda'].mean()
rf_pre_mape_averages.iloc[1,1] = rf_pre_mape[rf_pre_mape['company'].isin(companies_large)]['mda'].mean()
rf_pre_mape_averages.iloc[2,1] = rf_pre_mape[rf_pre_mape['company'].isin(companies_mid)]['mda'].mean()
rf_pre_mape_averages.iloc[3,1] = rf_pre_mape[rf_pre_mape['company'].isin(companies_small)]['mda'].mean()
rf_pre_mape_averages.iloc[4,1] = rf_pre_mape[rf_pre_mape['company'].isin(indices)]['mda'].mean()

rf_pre_mape_averages.iloc[0,2] = rf_pre_mape['hr'].mean()
rf_pre_mape_averages.iloc[1,2] = rf_pre_mape[rf_pre_mape['company'].isin(companies_large)]['hr'].mean()
rf_pre_mape_averages.iloc[2,2] = rf_pre_mape[rf_pre_mape['company'].isin(companies_mid)]['hr'].mean()
rf_pre_mape_averages.iloc[3,2] = rf_pre_mape[rf_pre_mape['company'].isin(companies_small)]['hr'].mean()
rf_pre_mape_averages.iloc[4,2] = rf_pre_mape[rf_pre_mape['company'].isin(indices)]['hr'].mean()




rf_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_pre_hr_averages.iloc[0,0] = rf_pre_hr['mape'].mean()
rf_pre_hr_averages.iloc[1,0] = rf_pre_hr[rf_pre_hr['company'].isin(companies_large)]['mape'].mean()
rf_pre_hr_averages.iloc[2,0] = rf_pre_hr[rf_pre_hr['company'].isin(companies_mid)]['mape'].mean()
rf_pre_hr_averages.iloc[3,0] = rf_pre_hr[rf_pre_hr['company'].isin(companies_small)]['mape'].mean()
rf_pre_hr_averages.iloc[4,0] = rf_pre_hr[rf_pre_hr['company'].isin(indices)]['mape'].mean()

rf_pre_hr_averages.iloc[0,1] = rf_pre_hr['mda'].mean()
rf_pre_hr_averages.iloc[1,1] = rf_pre_hr[rf_pre_hr['company'].isin(companies_large)]['mda'].mean()
rf_pre_hr_averages.iloc[2,1] = rf_pre_hr[rf_pre_hr['company'].isin(companies_mid)]['mda'].mean()
rf_pre_hr_averages.iloc[3,1] = rf_pre_hr[rf_pre_hr['company'].isin(companies_small)]['mda'].mean()
rf_pre_hr_averages.iloc[4,1] = rf_pre_hr[rf_pre_hr['company'].isin(indices)]['mda'].mean()

rf_pre_hr_averages.iloc[0,2] = rf_pre_hr['hr'].mean()
rf_pre_hr_averages.iloc[1,2] = rf_pre_hr[rf_pre_hr['company'].isin(companies_large)]['hr'].mean()
rf_pre_hr_averages.iloc[2,2] = rf_pre_hr[rf_pre_hr['company'].isin(companies_mid)]['hr'].mean()
rf_pre_hr_averages.iloc[3,2] = rf_pre_hr[rf_pre_hr['company'].isin(companies_small)]['hr'].mean()
rf_pre_hr_averages.iloc[4,2] = rf_pre_hr[rf_pre_hr['company'].isin(indices)]['hr'].mean()




rf_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_post_mda_averages.iloc[0,0] = rf_post_mda['mape'].mean()
rf_post_mda_averages.iloc[1,0] = rf_post_mda[rf_post_mda['company'].isin(companies_large)]['mape'].mean()
rf_post_mda_averages.iloc[2,0] = rf_post_mda[rf_post_mda['company'].isin(companies_mid)]['mape'].mean()
rf_post_mda_averages.iloc[3,0] = rf_post_mda[rf_post_mda['company'].isin(companies_small)]['mape'].mean()
rf_post_mda_averages.iloc[4,0] = rf_post_mda[rf_post_mda['company'].isin(indices)]['mape'].mean()

rf_post_mda_averages.iloc[0,1] = rf_post_mda['mda'].mean()
rf_post_mda_averages.iloc[1,1] = rf_post_mda[rf_post_mda['company'].isin(companies_large)]['mda'].mean()
rf_post_mda_averages.iloc[2,1] = rf_post_mda[rf_post_mda['company'].isin(companies_mid)]['mda'].mean()
rf_post_mda_averages.iloc[3,1] = rf_post_mda[rf_post_mda['company'].isin(companies_small)]['mda'].mean()
rf_post_mda_averages.iloc[4,1] = rf_post_mda[rf_post_mda['company'].isin(indices)]['mda'].mean()

rf_post_mda_averages.iloc[0,2] = rf_post_mda['hr'].mean()
rf_post_mda_averages.iloc[1,2] = rf_post_mda[rf_post_mda['company'].isin(companies_large)]['hr'].mean()
rf_post_mda_averages.iloc[2,2] = rf_post_mda[rf_post_mda['company'].isin(companies_mid)]['hr'].mean()
rf_post_mda_averages.iloc[3,2] = rf_post_mda[rf_post_mda['company'].isin(companies_small)]['hr'].mean()
rf_post_mda_averages.iloc[4,2] = rf_post_mda[rf_post_mda['company'].isin(indices)]['hr'].mean()





rf_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_post_mape_averages.iloc[0,0] = rf_post_mape['mape'].mean()
rf_post_mape_averages.iloc[1,0] = rf_post_mape[rf_post_mape['company'].isin(companies_large)]['mape'].mean()
rf_post_mape_averages.iloc[2,0] = rf_post_mape[rf_post_mape['company'].isin(companies_mid)]['mape'].mean()
rf_post_mape_averages.iloc[3,0] = rf_post_mape[rf_post_mape['company'].isin(companies_small)]['mape'].mean()
rf_post_mape_averages.iloc[4,0] = rf_post_mape[rf_post_mape['company'].isin(indices)]['mape'].mean()

rf_post_mape_averages.iloc[0,1] = rf_post_mape['mda'].mean()
rf_post_mape_averages.iloc[1,1] = rf_post_mape[rf_post_mape['company'].isin(companies_large)]['mda'].mean()
rf_post_mape_averages.iloc[2,1] = rf_post_mape[rf_post_mape['company'].isin(companies_mid)]['mda'].mean()
rf_post_mape_averages.iloc[3,1] = rf_post_mape[rf_post_mape['company'].isin(companies_small)]['mda'].mean()
rf_post_mape_averages.iloc[4,1] = rf_post_mape[rf_post_mape['company'].isin(indices)]['mda'].mean()

rf_post_mape_averages.iloc[0,2] = rf_post_mape['hr'].mean()
rf_post_mape_averages.iloc[1,2] = rf_post_mape[rf_post_mape['company'].isin(companies_large)]['hr'].mean()
rf_post_mape_averages.iloc[2,2] = rf_post_mape[rf_post_mape['company'].isin(companies_mid)]['hr'].mean()
rf_post_mape_averages.iloc[3,2] = rf_post_mape[rf_post_mape['company'].isin(companies_small)]['hr'].mean()
rf_post_mape_averages.iloc[4,2] = rf_post_mape[rf_post_mape['company'].isin(indices)]['hr'].mean()




rf_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

rf_post_hr_averages.iloc[0,0] = rf_post_hr['mape'].mean()
rf_post_hr_averages.iloc[1,0] = rf_post_hr[rf_post_hr['company'].isin(companies_large)]['mape'].mean()
rf_post_hr_averages.iloc[2,0] = rf_post_hr[rf_post_hr['company'].isin(companies_mid)]['mape'].mean()
rf_post_hr_averages.iloc[3,0] = rf_post_hr[rf_post_hr['company'].isin(companies_small)]['mape'].mean()
rf_post_hr_averages.iloc[4,0] = rf_post_hr[rf_post_hr['company'].isin(indices)]['mape'].mean()

rf_post_hr_averages.iloc[0,1] = rf_post_hr['mda'].mean()
rf_post_hr_averages.iloc[1,1] = rf_post_hr[rf_post_hr['company'].isin(companies_large)]['mda'].mean()
rf_post_hr_averages.iloc[2,1] = rf_post_hr[rf_post_hr['company'].isin(companies_mid)]['mda'].mean()
rf_post_hr_averages.iloc[3,1] = rf_post_hr[rf_post_hr['company'].isin(companies_small)]['mda'].mean()
rf_post_hr_averages.iloc[4,1] = rf_post_hr[rf_post_hr['company'].isin(indices)]['mda'].mean()

rf_post_hr_averages.iloc[0,2] = rf_post_hr['hr'].mean()
rf_post_hr_averages.iloc[1,2] = rf_post_hr[rf_post_hr['company'].isin(companies_large)]['hr'].mean()
rf_post_hr_averages.iloc[2,2] = rf_post_hr[rf_post_hr['company'].isin(companies_mid)]['hr'].mean()
rf_post_hr_averages.iloc[3,2] = rf_post_hr[rf_post_hr['company'].isin(companies_small)]['hr'].mean()
rf_post_hr_averages.iloc[4,2] = rf_post_hr[rf_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # Extra trees

# %%
et_pre_hr = pd.DataFrame()
et_pre_mda = pd.DataFrame()
et_pre_mape = pd.DataFrame()

et_post_hr = pd.DataFrame()
et_post_mda = pd.DataFrame()
et_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(et_pre[et_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    et_pre_hr = pd.concat([et_pre_hr, best])

    best = pd.DataFrame(et_pre[et_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    et_pre_mda = pd.concat([et_pre_mda, best])

    best = pd.DataFrame(et_pre[et_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    et_pre_mape = pd.concat([et_pre_mape, best])


    #post covid
    best = pd.DataFrame(et_post[et_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    et_post_hr = pd.concat([et_post_hr, best])

    best = pd.DataFrame(et_post[et_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    et_post_mda = pd.concat([et_post_mda, best])

    best = pd.DataFrame(et_post[et_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    et_post_mape = pd.concat([et_post_mape, best])

# %%
et_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_pre_mda_averages.iloc[0,0] = et_pre_mda['mape'].mean()
et_pre_mda_averages.iloc[1,0] = et_pre_mda[et_pre_mda['company'].isin(companies_large)]['mape'].mean()
et_pre_mda_averages.iloc[2,0] = et_pre_mda[et_pre_mda['company'].isin(companies_mid)]['mape'].mean()
et_pre_mda_averages.iloc[3,0] = et_pre_mda[et_pre_mda['company'].isin(companies_small)]['mape'].mean()
et_pre_mda_averages.iloc[4,0] = et_pre_mda[et_pre_mda['company'].isin(indices)]['mape'].mean()

et_pre_mda_averages.iloc[0,1] = et_pre_mda['mda'].mean()
et_pre_mda_averages.iloc[1,1] = et_pre_mda[et_pre_mda['company'].isin(companies_large)]['mda'].mean()
et_pre_mda_averages.iloc[2,1] = et_pre_mda[et_pre_mda['company'].isin(companies_mid)]['mda'].mean()
et_pre_mda_averages.iloc[3,1] = et_pre_mda[et_pre_mda['company'].isin(companies_small)]['mda'].mean()
et_pre_mda_averages.iloc[4,1] = et_pre_mda[et_pre_mda['company'].isin(indices)]['mda'].mean()

et_pre_mda_averages.iloc[0,2] = et_pre_mda['hr'].mean()
et_pre_mda_averages.iloc[1,2] = et_pre_mda[et_pre_mda['company'].isin(companies_large)]['hr'].mean()
et_pre_mda_averages.iloc[2,2] = et_pre_mda[et_pre_mda['company'].isin(companies_mid)]['hr'].mean()
et_pre_mda_averages.iloc[3,2] = et_pre_mda[et_pre_mda['company'].isin(companies_small)]['hr'].mean()
et_pre_mda_averages.iloc[4,2] = et_pre_mda[et_pre_mda['company'].isin(indices)]['hr'].mean()





et_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_pre_mape_averages.iloc[0,0] = et_pre_mape['mape'].mean()
et_pre_mape_averages.iloc[1,0] = et_pre_mape[et_pre_mape['company'].isin(companies_large)]['mape'].mean()
et_pre_mape_averages.iloc[2,0] = et_pre_mape[et_pre_mape['company'].isin(companies_mid)]['mape'].mean()
et_pre_mape_averages.iloc[3,0] = et_pre_mape[et_pre_mape['company'].isin(companies_small)]['mape'].mean()
et_pre_mape_averages.iloc[4,0] = et_pre_mape[et_pre_mape['company'].isin(indices)]['mape'].mean()

et_pre_mape_averages.iloc[0,1] = et_pre_mape['mda'].mean()
et_pre_mape_averages.iloc[1,1] = et_pre_mape[et_pre_mape['company'].isin(companies_large)]['mda'].mean()
et_pre_mape_averages.iloc[2,1] = et_pre_mape[et_pre_mape['company'].isin(companies_mid)]['mda'].mean()
et_pre_mape_averages.iloc[3,1] = et_pre_mape[et_pre_mape['company'].isin(companies_small)]['mda'].mean()
et_pre_mape_averages.iloc[4,1] = et_pre_mape[et_pre_mape['company'].isin(indices)]['mda'].mean()

et_pre_mape_averages.iloc[0,2] = et_pre_mape['hr'].mean()
et_pre_mape_averages.iloc[1,2] = et_pre_mape[et_pre_mape['company'].isin(companies_large)]['hr'].mean()
et_pre_mape_averages.iloc[2,2] = et_pre_mape[et_pre_mape['company'].isin(companies_mid)]['hr'].mean()
et_pre_mape_averages.iloc[3,2] = et_pre_mape[et_pre_mape['company'].isin(companies_small)]['hr'].mean()
et_pre_mape_averages.iloc[4,2] = et_pre_mape[et_pre_mape['company'].isin(indices)]['hr'].mean()




et_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_pre_hr_averages.iloc[0,0] = et_pre_hr['mape'].mean()
et_pre_hr_averages.iloc[1,0] = et_pre_hr[et_pre_hr['company'].isin(companies_large)]['mape'].mean()
et_pre_hr_averages.iloc[2,0] = et_pre_hr[et_pre_hr['company'].isin(companies_mid)]['mape'].mean()
et_pre_hr_averages.iloc[3,0] = et_pre_hr[et_pre_hr['company'].isin(companies_small)]['mape'].mean()
et_pre_hr_averages.iloc[4,0] = et_pre_hr[et_pre_hr['company'].isin(indices)]['mape'].mean()

et_pre_hr_averages.iloc[0,1] = et_pre_hr['mda'].mean()
et_pre_hr_averages.iloc[1,1] = et_pre_hr[et_pre_hr['company'].isin(companies_large)]['mda'].mean()
et_pre_hr_averages.iloc[2,1] = et_pre_hr[et_pre_hr['company'].isin(companies_mid)]['mda'].mean()
et_pre_hr_averages.iloc[3,1] = et_pre_hr[et_pre_hr['company'].isin(companies_small)]['mda'].mean()
et_pre_hr_averages.iloc[4,1] = et_pre_hr[et_pre_hr['company'].isin(indices)]['mda'].mean()

et_pre_hr_averages.iloc[0,2] = et_pre_hr['hr'].mean()
et_pre_hr_averages.iloc[1,2] = et_pre_hr[et_pre_hr['company'].isin(companies_large)]['hr'].mean()
et_pre_hr_averages.iloc[2,2] = et_pre_hr[et_pre_hr['company'].isin(companies_mid)]['hr'].mean()
et_pre_hr_averages.iloc[3,2] = et_pre_hr[et_pre_hr['company'].isin(companies_small)]['hr'].mean()
et_pre_hr_averages.iloc[4,2] = et_pre_hr[et_pre_hr['company'].isin(indices)]['hr'].mean()



et_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_post_mda_averages.iloc[0,0] = et_post_mda['mape'].mean()
et_post_mda_averages.iloc[1,0] = et_post_mda[et_post_mda['company'].isin(companies_large)]['mape'].mean()
et_post_mda_averages.iloc[2,0] = et_post_mda[et_post_mda['company'].isin(companies_mid)]['mape'].mean()
et_post_mda_averages.iloc[3,0] = et_post_mda[et_post_mda['company'].isin(companies_small)]['mape'].mean()
et_post_mda_averages.iloc[4,0] = et_post_mda[et_post_mda['company'].isin(indices)]['mape'].mean()

et_post_mda_averages.iloc[0,1] = et_post_mda['mda'].mean()
et_post_mda_averages.iloc[1,1] = et_post_mda[et_post_mda['company'].isin(companies_large)]['mda'].mean()
et_post_mda_averages.iloc[2,1] = et_post_mda[et_post_mda['company'].isin(companies_mid)]['mda'].mean()
et_post_mda_averages.iloc[3,1] = et_post_mda[et_post_mda['company'].isin(companies_small)]['mda'].mean()
et_post_mda_averages.iloc[4,1] = et_post_mda[et_post_mda['company'].isin(indices)]['mda'].mean()

et_post_mda_averages.iloc[0,2] = et_post_mda['hr'].mean()
et_post_mda_averages.iloc[1,2] = et_post_mda[et_post_mda['company'].isin(companies_large)]['hr'].mean()
et_post_mda_averages.iloc[2,2] = et_post_mda[et_post_mda['company'].isin(companies_mid)]['hr'].mean()
et_post_mda_averages.iloc[3,2] = et_post_mda[et_post_mda['company'].isin(companies_small)]['hr'].mean()
et_post_mda_averages.iloc[4,2] = et_post_mda[et_post_mda['company'].isin(indices)]['hr'].mean()





et_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_post_mape_averages.iloc[0,0] = et_post_mape['mape'].mean()
et_post_mape_averages.iloc[1,0] = et_post_mape[et_post_mape['company'].isin(companies_large)]['mape'].mean()
et_post_mape_averages.iloc[2,0] = et_post_mape[et_post_mape['company'].isin(companies_mid)]['mape'].mean()
et_post_mape_averages.iloc[3,0] = et_post_mape[et_post_mape['company'].isin(companies_small)]['mape'].mean()
et_post_mape_averages.iloc[4,0] = et_post_mape[et_post_mape['company'].isin(indices)]['mape'].mean()

et_post_mape_averages.iloc[0,1] = et_post_mape['mda'].mean()
et_post_mape_averages.iloc[1,1] = et_post_mape[et_post_mape['company'].isin(companies_large)]['mda'].mean()
et_post_mape_averages.iloc[2,1] = et_post_mape[et_post_mape['company'].isin(companies_mid)]['mda'].mean()
et_post_mape_averages.iloc[3,1] = et_post_mape[et_post_mape['company'].isin(companies_small)]['mda'].mean()
et_post_mape_averages.iloc[4,1] = et_post_mape[et_post_mape['company'].isin(indices)]['mda'].mean()

et_post_mape_averages.iloc[0,2] = et_post_mape['hr'].mean()
et_post_mape_averages.iloc[1,2] = et_post_mape[et_post_mape['company'].isin(companies_large)]['hr'].mean()
et_post_mape_averages.iloc[2,2] = et_post_mape[et_post_mape['company'].isin(companies_mid)]['hr'].mean()
et_post_mape_averages.iloc[3,2] = et_post_mape[et_post_mape['company'].isin(companies_small)]['hr'].mean()
et_post_mape_averages.iloc[4,2] = et_post_mape[et_post_mape['company'].isin(indices)]['hr'].mean()




et_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

et_post_hr_averages.iloc[0,0] = et_post_hr['mape'].mean()
et_post_hr_averages.iloc[1,0] = et_post_hr[et_post_hr['company'].isin(companies_large)]['mape'].mean()
et_post_hr_averages.iloc[2,0] = et_post_hr[et_post_hr['company'].isin(companies_mid)]['mape'].mean()
et_post_hr_averages.iloc[3,0] = et_post_hr[et_post_hr['company'].isin(companies_small)]['mape'].mean()
et_post_hr_averages.iloc[4,0] = et_post_hr[et_post_hr['company'].isin(indices)]['mape'].mean()

et_post_hr_averages.iloc[0,1] = et_post_hr['mda'].mean()
et_post_hr_averages.iloc[1,1] = et_post_hr[et_post_hr['company'].isin(companies_large)]['mda'].mean()
et_post_hr_averages.iloc[2,1] = et_post_hr[et_post_hr['company'].isin(companies_mid)]['mda'].mean()
et_post_hr_averages.iloc[3,1] = et_post_hr[et_post_hr['company'].isin(companies_small)]['mda'].mean()
et_post_hr_averages.iloc[4,1] = et_post_hr[et_post_hr['company'].isin(indices)]['mda'].mean()

et_post_hr_averages.iloc[0,2] = et_post_hr['hr'].mean()
et_post_hr_averages.iloc[1,2] = et_post_hr[et_post_hr['company'].isin(companies_large)]['hr'].mean()
et_post_hr_averages.iloc[2,2] = et_post_hr[et_post_hr['company'].isin(companies_mid)]['hr'].mean()
et_post_hr_averages.iloc[3,2] = et_post_hr[et_post_hr['company'].isin(companies_small)]['hr'].mean()
et_post_hr_averages.iloc[4,2] = et_post_hr[et_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # LSTM

# %%
lstm_pre_hr = pd.DataFrame()
lstm_pre_mda = pd.DataFrame()
lstm_pre_mape = pd.DataFrame()

lstm_post_hr = pd.DataFrame()
lstm_post_mda = pd.DataFrame()
lstm_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(lstm_pre[lstm_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    lstm_pre_hr = pd.concat([lstm_pre_hr, best])

    best = pd.DataFrame(lstm_pre[lstm_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    lstm_pre_mda = pd.concat([lstm_pre_mda, best])

    best = pd.DataFrame(lstm_pre[lstm_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    lstm_pre_mape = pd.concat([lstm_pre_mape, best])


    #post covid
    best = pd.DataFrame(lstm_post[lstm_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    lstm_post_hr = pd.concat([lstm_post_hr, best])

    best = pd.DataFrame(lstm_post[lstm_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    lstm_post_mda = pd.concat([lstm_post_mda, best])

    best = pd.DataFrame(lstm_post[lstm_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    lstm_post_mape = pd.concat([lstm_post_mape, best])

# %%
lstm_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_pre_mda_averages.iloc[0,0] = lstm_pre_mda['mape'].mean()
lstm_pre_mda_averages.iloc[1,0] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_large)]['mape'].mean()
lstm_pre_mda_averages.iloc[2,0] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_mid)]['mape'].mean()
lstm_pre_mda_averages.iloc[3,0] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_small)]['mape'].mean()
lstm_pre_mda_averages.iloc[4,0] = lstm_pre_mda[lstm_pre_mda['company'].isin(indices)]['mape'].mean()

lstm_pre_mda_averages.iloc[0,1] = lstm_pre_mda['mda'].mean()
lstm_pre_mda_averages.iloc[1,1] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_large)]['mda'].mean()
lstm_pre_mda_averages.iloc[2,1] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_mid)]['mda'].mean()
lstm_pre_mda_averages.iloc[3,1] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_small)]['mda'].mean()
lstm_pre_mda_averages.iloc[4,1] = lstm_pre_mda[lstm_pre_mda['company'].isin(indices)]['mda'].mean()

lstm_pre_mda_averages.iloc[0,2] = lstm_pre_mda['hr'].mean()
lstm_pre_mda_averages.iloc[1,2] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_large)]['hr'].mean()
lstm_pre_mda_averages.iloc[2,2] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_mid)]['hr'].mean()
lstm_pre_mda_averages.iloc[3,2] = lstm_pre_mda[lstm_pre_mda['company'].isin(companies_small)]['hr'].mean()
lstm_pre_mda_averages.iloc[4,2] = lstm_pre_mda[lstm_pre_mda['company'].isin(indices)]['hr'].mean()





lstm_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_pre_mape_averages.iloc[0,0] = lstm_pre_mape['mape'].mean()
lstm_pre_mape_averages.iloc[1,0] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_large)]['mape'].mean()
lstm_pre_mape_averages.iloc[2,0] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_mid)]['mape'].mean()
lstm_pre_mape_averages.iloc[3,0] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_small)]['mape'].mean()
lstm_pre_mape_averages.iloc[4,0] = lstm_pre_mape[lstm_pre_mape['company'].isin(indices)]['mape'].mean()

lstm_pre_mape_averages.iloc[0,1] = lstm_pre_mape['mda'].mean()
lstm_pre_mape_averages.iloc[1,1] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_large)]['mda'].mean()
lstm_pre_mape_averages.iloc[2,1] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_mid)]['mda'].mean()
lstm_pre_mape_averages.iloc[3,1] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_small)]['mda'].mean()
lstm_pre_mape_averages.iloc[4,1] = lstm_pre_mape[lstm_pre_mape['company'].isin(indices)]['mda'].mean()

lstm_pre_mape_averages.iloc[0,2] = lstm_pre_mape['hr'].mean()
lstm_pre_mape_averages.iloc[1,2] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_large)]['hr'].mean()
lstm_pre_mape_averages.iloc[2,2] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_mid)]['hr'].mean()
lstm_pre_mape_averages.iloc[3,2] = lstm_pre_mape[lstm_pre_mape['company'].isin(companies_small)]['hr'].mean()
lstm_pre_mape_averages.iloc[4,2] = lstm_pre_mape[lstm_pre_mape['company'].isin(indices)]['hr'].mean()




lstm_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_pre_hr_averages.iloc[0,0] = lstm_pre_hr['mape'].mean()
lstm_pre_hr_averages.iloc[1,0] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_large)]['mape'].mean()
lstm_pre_hr_averages.iloc[2,0] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_mid)]['mape'].mean()
lstm_pre_hr_averages.iloc[3,0] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_small)]['mape'].mean()
lstm_pre_hr_averages.iloc[4,0] = lstm_pre_hr[lstm_pre_hr['company'].isin(indices)]['mape'].mean()

lstm_pre_hr_averages.iloc[0,1] = lstm_pre_hr['mda'].mean()
lstm_pre_hr_averages.iloc[1,1] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_large)]['mda'].mean()
lstm_pre_hr_averages.iloc[2,1] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_mid)]['mda'].mean()
lstm_pre_hr_averages.iloc[3,1] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_small)]['mda'].mean()
lstm_pre_hr_averages.iloc[4,1] = lstm_pre_hr[lstm_pre_hr['company'].isin(indices)]['mda'].mean()

lstm_pre_hr_averages.iloc[0,2] = lstm_pre_hr['hr'].mean()
lstm_pre_hr_averages.iloc[1,2] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_large)]['hr'].mean()
lstm_pre_hr_averages.iloc[2,2] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_mid)]['hr'].mean()
lstm_pre_hr_averages.iloc[3,2] = lstm_pre_hr[lstm_pre_hr['company'].isin(companies_small)]['hr'].mean()
lstm_pre_hr_averages.iloc[4,2] = lstm_pre_hr[lstm_pre_hr['company'].isin(indices)]['hr'].mean()



lstm_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_post_mda_averages.iloc[0,0] = lstm_post_mda['mape'].mean()
lstm_post_mda_averages.iloc[1,0] = lstm_post_mda[lstm_post_mda['company'].isin(companies_large)]['mape'].mean()
lstm_post_mda_averages.iloc[2,0] = lstm_post_mda[lstm_post_mda['company'].isin(companies_mid)]['mape'].mean()
lstm_post_mda_averages.iloc[3,0] = lstm_post_mda[lstm_post_mda['company'].isin(companies_small)]['mape'].mean()
lstm_post_mda_averages.iloc[4,0] = lstm_post_mda[lstm_post_mda['company'].isin(indices)]['mape'].mean()

lstm_post_mda_averages.iloc[0,1] = lstm_post_mda['mda'].mean()
lstm_post_mda_averages.iloc[1,1] = lstm_post_mda[lstm_post_mda['company'].isin(companies_large)]['mda'].mean()
lstm_post_mda_averages.iloc[2,1] = lstm_post_mda[lstm_post_mda['company'].isin(companies_mid)]['mda'].mean()
lstm_post_mda_averages.iloc[3,1] = lstm_post_mda[lstm_post_mda['company'].isin(companies_small)]['mda'].mean()
lstm_post_mda_averages.iloc[4,1] = lstm_post_mda[lstm_post_mda['company'].isin(indices)]['mda'].mean()

lstm_post_mda_averages.iloc[0,2] = lstm_post_mda['hr'].mean()
lstm_post_mda_averages.iloc[1,2] = lstm_post_mda[lstm_post_mda['company'].isin(companies_large)]['hr'].mean()
lstm_post_mda_averages.iloc[2,2] = lstm_post_mda[lstm_post_mda['company'].isin(companies_mid)]['hr'].mean()
lstm_post_mda_averages.iloc[3,2] = lstm_post_mda[lstm_post_mda['company'].isin(companies_small)]['hr'].mean()
lstm_post_mda_averages.iloc[4,2] = lstm_post_mda[lstm_post_mda['company'].isin(indices)]['hr'].mean()





lstm_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_post_mape_averages.iloc[0,0] = lstm_post_mape['mape'].mean()
lstm_post_mape_averages.iloc[1,0] = lstm_post_mape[lstm_post_mape['company'].isin(companies_large)]['mape'].mean()
lstm_post_mape_averages.iloc[2,0] = lstm_post_mape[lstm_post_mape['company'].isin(companies_mid)]['mape'].mean()
lstm_post_mape_averages.iloc[3,0] = lstm_post_mape[lstm_post_mape['company'].isin(companies_small)]['mape'].mean()
lstm_post_mape_averages.iloc[4,0] = lstm_post_mape[lstm_post_mape['company'].isin(indices)]['mape'].mean()

lstm_post_mape_averages.iloc[0,1] = lstm_post_mape['mda'].mean()
lstm_post_mape_averages.iloc[1,1] = lstm_post_mape[lstm_post_mape['company'].isin(companies_large)]['mda'].mean()
lstm_post_mape_averages.iloc[2,1] = lstm_post_mape[lstm_post_mape['company'].isin(companies_mid)]['mda'].mean()
lstm_post_mape_averages.iloc[3,1] = lstm_post_mape[lstm_post_mape['company'].isin(companies_small)]['mda'].mean()
lstm_post_mape_averages.iloc[4,1] = lstm_post_mape[lstm_post_mape['company'].isin(indices)]['mda'].mean()

lstm_post_mape_averages.iloc[0,2] = lstm_post_mape['hr'].mean()
lstm_post_mape_averages.iloc[1,2] = lstm_post_mape[lstm_post_mape['company'].isin(companies_large)]['hr'].mean()
lstm_post_mape_averages.iloc[2,2] = lstm_post_mape[lstm_post_mape['company'].isin(companies_mid)]['hr'].mean()
lstm_post_mape_averages.iloc[3,2] = lstm_post_mape[lstm_post_mape['company'].isin(companies_small)]['hr'].mean()
lstm_post_mape_averages.iloc[4,2] = lstm_post_mape[lstm_post_mape['company'].isin(indices)]['hr'].mean()




lstm_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

lstm_post_hr_averages.iloc[0,0] = lstm_post_hr['mape'].mean()
lstm_post_hr_averages.iloc[1,0] = lstm_post_hr[lstm_post_hr['company'].isin(companies_large)]['mape'].mean()
lstm_post_hr_averages.iloc[2,0] = lstm_post_hr[lstm_post_hr['company'].isin(companies_mid)]['mape'].mean()
lstm_post_hr_averages.iloc[3,0] = lstm_post_hr[lstm_post_hr['company'].isin(companies_small)]['mape'].mean()
lstm_post_hr_averages.iloc[4,0] = lstm_post_hr[lstm_post_hr['company'].isin(indices)]['mape'].mean()

lstm_post_hr_averages.iloc[0,1] = lstm_post_hr['mda'].mean()
lstm_post_hr_averages.iloc[1,1] = lstm_post_hr[lstm_post_hr['company'].isin(companies_large)]['mda'].mean()
lstm_post_hr_averages.iloc[2,1] = lstm_post_hr[lstm_post_hr['company'].isin(companies_mid)]['mda'].mean()
lstm_post_hr_averages.iloc[3,1] = lstm_post_hr[lstm_post_hr['company'].isin(companies_small)]['mda'].mean()
lstm_post_hr_averages.iloc[4,1] = lstm_post_hr[lstm_post_hr['company'].isin(indices)]['mda'].mean()

lstm_post_hr_averages.iloc[0,2] = lstm_post_hr['hr'].mean()
lstm_post_hr_averages.iloc[1,2] = lstm_post_hr[lstm_post_hr['company'].isin(companies_large)]['hr'].mean()
lstm_post_hr_averages.iloc[2,2] = lstm_post_hr[lstm_post_hr['company'].isin(companies_mid)]['hr'].mean()
lstm_post_hr_averages.iloc[3,2] = lstm_post_hr[lstm_post_hr['company'].isin(companies_small)]['hr'].mean()
lstm_post_hr_averages.iloc[4,2] = lstm_post_hr[lstm_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # MLP

# %%
mlp_pre_hr = pd.DataFrame()
mlp_pre_mda = pd.DataFrame()
mlp_pre_mape = pd.DataFrame()

mlp_post_hr = pd.DataFrame()
mlp_post_mda = pd.DataFrame()
mlp_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(mlp_pre[mlp_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    mlp_pre_hr = pd.concat([mlp_pre_hr, best])

    best = pd.DataFrame(mlp_pre[mlp_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    mlp_pre_mda = pd.concat([mlp_pre_mda, best])

    best = pd.DataFrame(mlp_pre[mlp_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    mlp_pre_mape = pd.concat([mlp_pre_mape, best])


    #post covid
    best = pd.DataFrame(mlp_post[mlp_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    mlp_post_hr = pd.concat([mlp_post_hr, best])

    best = pd.DataFrame(mlp_post[mlp_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    mlp_post_mda = pd.concat([mlp_post_mda, best])

    best = pd.DataFrame(mlp_post[mlp_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    mlp_post_mape = pd.concat([mlp_post_mape, best])

# %%
mlp_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_pre_mda_averages.iloc[0,0] = mlp_pre_mda['mape'].mean()
mlp_pre_mda_averages.iloc[1,0] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_large)]['mape'].mean()
mlp_pre_mda_averages.iloc[2,0] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_mid)]['mape'].mean()
mlp_pre_mda_averages.iloc[3,0] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_small)]['mape'].mean()
mlp_pre_mda_averages.iloc[4,0] = mlp_pre_mda[mlp_pre_mda['company'].isin(indices)]['mape'].mean()

mlp_pre_mda_averages.iloc[0,1] = mlp_pre_mda['mda'].mean()
mlp_pre_mda_averages.iloc[1,1] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_large)]['mda'].mean()
mlp_pre_mda_averages.iloc[2,1] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_mid)]['mda'].mean()
mlp_pre_mda_averages.iloc[3,1] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_small)]['mda'].mean()
mlp_pre_mda_averages.iloc[4,1] = mlp_pre_mda[mlp_pre_mda['company'].isin(indices)]['mda'].mean()

mlp_pre_mda_averages.iloc[0,2] = mlp_pre_mda['hr'].mean()
mlp_pre_mda_averages.iloc[1,2] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_large)]['hr'].mean()
mlp_pre_mda_averages.iloc[2,2] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_mid)]['hr'].mean()
mlp_pre_mda_averages.iloc[3,2] = mlp_pre_mda[mlp_pre_mda['company'].isin(companies_small)]['hr'].mean()
mlp_pre_mda_averages.iloc[4,2] = mlp_pre_mda[mlp_pre_mda['company'].isin(indices)]['hr'].mean()





mlp_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_pre_mape_averages.iloc[0,0] = mlp_pre_mape['mape'].mean()
mlp_pre_mape_averages.iloc[1,0] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_large)]['mape'].mean()
mlp_pre_mape_averages.iloc[2,0] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_mid)]['mape'].mean()
mlp_pre_mape_averages.iloc[3,0] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_small)]['mape'].mean()
mlp_pre_mape_averages.iloc[4,0] = mlp_pre_mape[mlp_pre_mape['company'].isin(indices)]['mape'].mean()

mlp_pre_mape_averages.iloc[0,1] = mlp_pre_mape['mda'].mean()
mlp_pre_mape_averages.iloc[1,1] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_large)]['mda'].mean()
mlp_pre_mape_averages.iloc[2,1] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_mid)]['mda'].mean()
mlp_pre_mape_averages.iloc[3,1] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_small)]['mda'].mean()
mlp_pre_mape_averages.iloc[4,1] = mlp_pre_mape[mlp_pre_mape['company'].isin(indices)]['mda'].mean()

mlp_pre_mape_averages.iloc[0,2] = mlp_pre_mape['hr'].mean()
mlp_pre_mape_averages.iloc[1,2] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_large)]['hr'].mean()
mlp_pre_mape_averages.iloc[2,2] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_mid)]['hr'].mean()
mlp_pre_mape_averages.iloc[3,2] = mlp_pre_mape[mlp_pre_mape['company'].isin(companies_small)]['hr'].mean()
mlp_pre_mape_averages.iloc[4,2] = mlp_pre_mape[mlp_pre_mape['company'].isin(indices)]['hr'].mean()




mlp_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_pre_hr_averages.iloc[0,0] = mlp_pre_hr['mape'].mean()
mlp_pre_hr_averages.iloc[1,0] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_large)]['mape'].mean()
mlp_pre_hr_averages.iloc[2,0] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_mid)]['mape'].mean()
mlp_pre_hr_averages.iloc[3,0] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_small)]['mape'].mean()
mlp_pre_hr_averages.iloc[4,0] = mlp_pre_hr[mlp_pre_hr['company'].isin(indices)]['mape'].mean()

mlp_pre_hr_averages.iloc[0,1] = mlp_pre_hr['mda'].mean()
mlp_pre_hr_averages.iloc[1,1] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_large)]['mda'].mean()
mlp_pre_hr_averages.iloc[2,1] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_mid)]['mda'].mean()
mlp_pre_hr_averages.iloc[3,1] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_small)]['mda'].mean()
mlp_pre_hr_averages.iloc[4,1] = mlp_pre_hr[mlp_pre_hr['company'].isin(indices)]['mda'].mean()

mlp_pre_hr_averages.iloc[0,2] = mlp_pre_hr['hr'].mean()
mlp_pre_hr_averages.iloc[1,2] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_large)]['hr'].mean()
mlp_pre_hr_averages.iloc[2,2] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_mid)]['hr'].mean()
mlp_pre_hr_averages.iloc[3,2] = mlp_pre_hr[mlp_pre_hr['company'].isin(companies_small)]['hr'].mean()
mlp_pre_hr_averages.iloc[4,2] = mlp_pre_hr[mlp_pre_hr['company'].isin(indices)]['hr'].mean()



mlp_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_post_mda_averages.iloc[0,0] = mlp_post_mda['mape'].mean()
mlp_post_mda_averages.iloc[1,0] = mlp_post_mda[mlp_post_mda['company'].isin(companies_large)]['mape'].mean()
mlp_post_mda_averages.iloc[2,0] = mlp_post_mda[mlp_post_mda['company'].isin(companies_mid)]['mape'].mean()
mlp_post_mda_averages.iloc[3,0] = mlp_post_mda[mlp_post_mda['company'].isin(companies_small)]['mape'].mean()
mlp_post_mda_averages.iloc[4,0] = mlp_post_mda[mlp_post_mda['company'].isin(indices)]['mape'].mean()

mlp_post_mda_averages.iloc[0,1] = mlp_post_mda['mda'].mean()
mlp_post_mda_averages.iloc[1,1] = mlp_post_mda[mlp_post_mda['company'].isin(companies_large)]['mda'].mean()
mlp_post_mda_averages.iloc[2,1] = mlp_post_mda[mlp_post_mda['company'].isin(companies_mid)]['mda'].mean()
mlp_post_mda_averages.iloc[3,1] = mlp_post_mda[mlp_post_mda['company'].isin(companies_small)]['mda'].mean()
mlp_post_mda_averages.iloc[4,1] = mlp_post_mda[mlp_post_mda['company'].isin(indices)]['mda'].mean()

mlp_post_mda_averages.iloc[0,2] = mlp_post_mda['hr'].mean()
mlp_post_mda_averages.iloc[1,2] = mlp_post_mda[mlp_post_mda['company'].isin(companies_large)]['hr'].mean()
mlp_post_mda_averages.iloc[2,2] = mlp_post_mda[mlp_post_mda['company'].isin(companies_mid)]['hr'].mean()
mlp_post_mda_averages.iloc[3,2] = mlp_post_mda[mlp_post_mda['company'].isin(companies_small)]['hr'].mean()
mlp_post_mda_averages.iloc[4,2] = mlp_post_mda[mlp_post_mda['company'].isin(indices)]['hr'].mean()





mlp_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_post_mape_averages.iloc[0,0] = mlp_post_mape['mape'].mean()
mlp_post_mape_averages.iloc[1,0] = mlp_post_mape[mlp_post_mape['company'].isin(companies_large)]['mape'].mean()
mlp_post_mape_averages.iloc[2,0] = mlp_post_mape[mlp_post_mape['company'].isin(companies_mid)]['mape'].mean()
mlp_post_mape_averages.iloc[3,0] = mlp_post_mape[mlp_post_mape['company'].isin(companies_small)]['mape'].mean()
mlp_post_mape_averages.iloc[4,0] = mlp_post_mape[mlp_post_mape['company'].isin(indices)]['mape'].mean()

mlp_post_mape_averages.iloc[0,1] = mlp_post_mape['mda'].mean()
mlp_post_mape_averages.iloc[1,1] = mlp_post_mape[mlp_post_mape['company'].isin(companies_large)]['mda'].mean()
mlp_post_mape_averages.iloc[2,1] = mlp_post_mape[mlp_post_mape['company'].isin(companies_mid)]['mda'].mean()
mlp_post_mape_averages.iloc[3,1] = mlp_post_mape[mlp_post_mape['company'].isin(companies_small)]['mda'].mean()
mlp_post_mape_averages.iloc[4,1] = mlp_post_mape[mlp_post_mape['company'].isin(indices)]['mda'].mean()

mlp_post_mape_averages.iloc[0,2] = mlp_post_mape['hr'].mean()
mlp_post_mape_averages.iloc[1,2] = mlp_post_mape[mlp_post_mape['company'].isin(companies_large)]['hr'].mean()
mlp_post_mape_averages.iloc[2,2] = mlp_post_mape[mlp_post_mape['company'].isin(companies_mid)]['hr'].mean()
mlp_post_mape_averages.iloc[3,2] = mlp_post_mape[mlp_post_mape['company'].isin(companies_small)]['hr'].mean()
mlp_post_mape_averages.iloc[4,2] = mlp_post_mape[mlp_post_mape['company'].isin(indices)]['hr'].mean()




mlp_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

mlp_post_hr_averages.iloc[0,0] = mlp_post_hr['mape'].mean()
mlp_post_hr_averages.iloc[1,0] = mlp_post_hr[mlp_post_hr['company'].isin(companies_large)]['mape'].mean()
mlp_post_hr_averages.iloc[2,0] = mlp_post_hr[mlp_post_hr['company'].isin(companies_mid)]['mape'].mean()
mlp_post_hr_averages.iloc[3,0] = mlp_post_hr[mlp_post_hr['company'].isin(companies_small)]['mape'].mean()
mlp_post_hr_averages.iloc[4,0] = mlp_post_hr[mlp_post_hr['company'].isin(indices)]['mape'].mean()

mlp_post_hr_averages.iloc[0,1] = mlp_post_hr['mda'].mean()
mlp_post_hr_averages.iloc[1,1] = mlp_post_hr[mlp_post_hr['company'].isin(companies_large)]['mda'].mean()
mlp_post_hr_averages.iloc[2,1] = mlp_post_hr[mlp_post_hr['company'].isin(companies_mid)]['mda'].mean()
mlp_post_hr_averages.iloc[3,1] = mlp_post_hr[mlp_post_hr['company'].isin(companies_small)]['mda'].mean()
mlp_post_hr_averages.iloc[4,1] = mlp_post_hr[mlp_post_hr['company'].isin(indices)]['mda'].mean()

mlp_post_hr_averages.iloc[0,2] = mlp_post_hr['hr'].mean()
mlp_post_hr_averages.iloc[1,2] = mlp_post_hr[mlp_post_hr['company'].isin(companies_large)]['hr'].mean()
mlp_post_hr_averages.iloc[2,2] = mlp_post_hr[mlp_post_hr['company'].isin(companies_mid)]['hr'].mean()
mlp_post_hr_averages.iloc[3,2] = mlp_post_hr[mlp_post_hr['company'].isin(companies_small)]['hr'].mean()
mlp_post_hr_averages.iloc[4,2] = mlp_post_hr[mlp_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # DNN

# %%
dnn_pre_hr = pd.DataFrame()
dnn_pre_mda = pd.DataFrame()
dnn_pre_mape = pd.DataFrame()

dnn_post_hr = pd.DataFrame()
dnn_post_mda = pd.DataFrame()
dnn_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(dnn_pre[dnn_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    dnn_pre_hr = pd.concat([dnn_pre_hr, best])

    best = pd.DataFrame(dnn_pre[dnn_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    dnn_pre_mda = pd.concat([dnn_pre_mda, best])

    best = pd.DataFrame(dnn_pre[dnn_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    dnn_pre_mape = pd.concat([dnn_pre_mape, best])


    #post covid
    best = pd.DataFrame(dnn_post[dnn_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    dnn_post_hr = pd.concat([dnn_post_hr, best])

    best = pd.DataFrame(dnn_post[dnn_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    dnn_post_mda = pd.concat([dnn_post_mda, best])

    best = pd.DataFrame(dnn_post[dnn_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    dnn_post_mape = pd.concat([dnn_post_mape, best])

# %%
dnn_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_pre_mda_averages.iloc[0,0] = dnn_pre_mda['mape'].mean()
dnn_pre_mda_averages.iloc[1,0] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_large)]['mape'].mean()
dnn_pre_mda_averages.iloc[2,0] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_mid)]['mape'].mean()
dnn_pre_mda_averages.iloc[3,0] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_small)]['mape'].mean()
dnn_pre_mda_averages.iloc[4,0] = dnn_pre_mda[dnn_pre_mda['company'].isin(indices)]['mape'].mean()

dnn_pre_mda_averages.iloc[0,1] = dnn_pre_mda['mda'].mean()
dnn_pre_mda_averages.iloc[1,1] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_large)]['mda'].mean()
dnn_pre_mda_averages.iloc[2,1] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_mid)]['mda'].mean()
dnn_pre_mda_averages.iloc[3,1] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_small)]['mda'].mean()
dnn_pre_mda_averages.iloc[4,1] = dnn_pre_mda[dnn_pre_mda['company'].isin(indices)]['mda'].mean()

dnn_pre_mda_averages.iloc[0,2] = dnn_pre_mda['hr'].mean()
dnn_pre_mda_averages.iloc[1,2] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_large)]['hr'].mean()
dnn_pre_mda_averages.iloc[2,2] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_mid)]['hr'].mean()
dnn_pre_mda_averages.iloc[3,2] = dnn_pre_mda[dnn_pre_mda['company'].isin(companies_small)]['hr'].mean()
dnn_pre_mda_averages.iloc[4,2] = dnn_pre_mda[dnn_pre_mda['company'].isin(indices)]['hr'].mean()





dnn_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_pre_mape_averages.iloc[0,0] = dnn_pre_mape['mape'].mean()
dnn_pre_mape_averages.iloc[1,0] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_large)]['mape'].mean()
dnn_pre_mape_averages.iloc[2,0] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_mid)]['mape'].mean()
dnn_pre_mape_averages.iloc[3,0] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_small)]['mape'].mean()
dnn_pre_mape_averages.iloc[4,0] = dnn_pre_mape[dnn_pre_mape['company'].isin(indices)]['mape'].mean()

dnn_pre_mape_averages.iloc[0,1] = dnn_pre_mape['mda'].mean()
dnn_pre_mape_averages.iloc[1,1] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_large)]['mda'].mean()
dnn_pre_mape_averages.iloc[2,1] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_mid)]['mda'].mean()
dnn_pre_mape_averages.iloc[3,1] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_small)]['mda'].mean()
dnn_pre_mape_averages.iloc[4,1] = dnn_pre_mape[dnn_pre_mape['company'].isin(indices)]['mda'].mean()

dnn_pre_mape_averages.iloc[0,2] = dnn_pre_mape['hr'].mean()
dnn_pre_mape_averages.iloc[1,2] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_large)]['hr'].mean()
dnn_pre_mape_averages.iloc[2,2] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_mid)]['hr'].mean()
dnn_pre_mape_averages.iloc[3,2] = dnn_pre_mape[dnn_pre_mape['company'].isin(companies_small)]['hr'].mean()
dnn_pre_mape_averages.iloc[4,2] = dnn_pre_mape[dnn_pre_mape['company'].isin(indices)]['hr'].mean()




dnn_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_pre_hr_averages.iloc[0,0] = dnn_pre_hr['mape'].mean()
dnn_pre_hr_averages.iloc[1,0] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_large)]['mape'].mean()
dnn_pre_hr_averages.iloc[2,0] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_mid)]['mape'].mean()
dnn_pre_hr_averages.iloc[3,0] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_small)]['mape'].mean()
dnn_pre_hr_averages.iloc[4,0] = dnn_pre_hr[dnn_pre_hr['company'].isin(indices)]['mape'].mean()

dnn_pre_hr_averages.iloc[0,1] = dnn_pre_hr['mda'].mean()
dnn_pre_hr_averages.iloc[1,1] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_large)]['mda'].mean()
dnn_pre_hr_averages.iloc[2,1] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_mid)]['mda'].mean()
dnn_pre_hr_averages.iloc[3,1] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_small)]['mda'].mean()
dnn_pre_hr_averages.iloc[4,1] = dnn_pre_hr[dnn_pre_hr['company'].isin(indices)]['mda'].mean()

dnn_pre_hr_averages.iloc[0,2] = dnn_pre_hr['hr'].mean()
dnn_pre_hr_averages.iloc[1,2] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_large)]['hr'].mean()
dnn_pre_hr_averages.iloc[2,2] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_mid)]['hr'].mean()
dnn_pre_hr_averages.iloc[3,2] = dnn_pre_hr[dnn_pre_hr['company'].isin(companies_small)]['hr'].mean()
dnn_pre_hr_averages.iloc[4,2] = dnn_pre_hr[dnn_pre_hr['company'].isin(indices)]['hr'].mean()



dnn_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_post_mda_averages.iloc[0,0] = dnn_post_mda['mape'].mean()
dnn_post_mda_averages.iloc[1,0] = dnn_post_mda[dnn_post_mda['company'].isin(companies_large)]['mape'].mean()
dnn_post_mda_averages.iloc[2,0] = dnn_post_mda[dnn_post_mda['company'].isin(companies_mid)]['mape'].mean()
dnn_post_mda_averages.iloc[3,0] = dnn_post_mda[dnn_post_mda['company'].isin(companies_small)]['mape'].mean()
dnn_post_mda_averages.iloc[4,0] = dnn_post_mda[dnn_post_mda['company'].isin(indices)]['mape'].mean()

dnn_post_mda_averages.iloc[0,1] = dnn_post_mda['mda'].mean()
dnn_post_mda_averages.iloc[1,1] = dnn_post_mda[dnn_post_mda['company'].isin(companies_large)]['mda'].mean()
dnn_post_mda_averages.iloc[2,1] = dnn_post_mda[dnn_post_mda['company'].isin(companies_mid)]['mda'].mean()
dnn_post_mda_averages.iloc[3,1] = dnn_post_mda[dnn_post_mda['company'].isin(companies_small)]['mda'].mean()
dnn_post_mda_averages.iloc[4,1] = dnn_post_mda[dnn_post_mda['company'].isin(indices)]['mda'].mean()

dnn_post_mda_averages.iloc[0,2] = dnn_post_mda['hr'].mean()
dnn_post_mda_averages.iloc[1,2] = dnn_post_mda[dnn_post_mda['company'].isin(companies_large)]['hr'].mean()
dnn_post_mda_averages.iloc[2,2] = dnn_post_mda[dnn_post_mda['company'].isin(companies_mid)]['hr'].mean()
dnn_post_mda_averages.iloc[3,2] = dnn_post_mda[dnn_post_mda['company'].isin(companies_small)]['hr'].mean()
dnn_post_mda_averages.iloc[4,2] = dnn_post_mda[dnn_post_mda['company'].isin(indices)]['hr'].mean()





dnn_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_post_mape_averages.iloc[0,0] = dnn_post_mape['mape'].mean()
dnn_post_mape_averages.iloc[1,0] = dnn_post_mape[dnn_post_mape['company'].isin(companies_large)]['mape'].mean()
dnn_post_mape_averages.iloc[2,0] = dnn_post_mape[dnn_post_mape['company'].isin(companies_mid)]['mape'].mean()
dnn_post_mape_averages.iloc[3,0] = dnn_post_mape[dnn_post_mape['company'].isin(companies_small)]['mape'].mean()
dnn_post_mape_averages.iloc[4,0] = dnn_post_mape[dnn_post_mape['company'].isin(indices)]['mape'].mean()

dnn_post_mape_averages.iloc[0,1] = dnn_post_mape['mda'].mean()
dnn_post_mape_averages.iloc[1,1] = dnn_post_mape[dnn_post_mape['company'].isin(companies_large)]['mda'].mean()
dnn_post_mape_averages.iloc[2,1] = dnn_post_mape[dnn_post_mape['company'].isin(companies_mid)]['mda'].mean()
dnn_post_mape_averages.iloc[3,1] = dnn_post_mape[dnn_post_mape['company'].isin(companies_small)]['mda'].mean()
dnn_post_mape_averages.iloc[4,1] = dnn_post_mape[dnn_post_mape['company'].isin(indices)]['mda'].mean()

dnn_post_mape_averages.iloc[0,2] = dnn_post_mape['hr'].mean()
dnn_post_mape_averages.iloc[1,2] = dnn_post_mape[dnn_post_mape['company'].isin(companies_large)]['hr'].mean()
dnn_post_mape_averages.iloc[2,2] = dnn_post_mape[dnn_post_mape['company'].isin(companies_mid)]['hr'].mean()
dnn_post_mape_averages.iloc[3,2] = dnn_post_mape[dnn_post_mape['company'].isin(companies_small)]['hr'].mean()
dnn_post_mape_averages.iloc[4,2] = dnn_post_mape[dnn_post_mape['company'].isin(indices)]['hr'].mean()




dnn_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

dnn_post_hr_averages.iloc[0,0] = dnn_post_hr['mape'].mean()
dnn_post_hr_averages.iloc[1,0] = dnn_post_hr[dnn_post_hr['company'].isin(companies_large)]['mape'].mean()
dnn_post_hr_averages.iloc[2,0] = dnn_post_hr[dnn_post_hr['company'].isin(companies_mid)]['mape'].mean()
dnn_post_hr_averages.iloc[3,0] = dnn_post_hr[dnn_post_hr['company'].isin(companies_small)]['mape'].mean()
dnn_post_hr_averages.iloc[4,0] = dnn_post_hr[dnn_post_hr['company'].isin(indices)]['mape'].mean()

dnn_post_hr_averages.iloc[0,1] = dnn_post_hr['mda'].mean()
dnn_post_hr_averages.iloc[1,1] = dnn_post_hr[dnn_post_hr['company'].isin(companies_large)]['mda'].mean()
dnn_post_hr_averages.iloc[2,1] = dnn_post_hr[dnn_post_hr['company'].isin(companies_mid)]['mda'].mean()
dnn_post_hr_averages.iloc[3,1] = dnn_post_hr[dnn_post_hr['company'].isin(companies_small)]['mda'].mean()
dnn_post_hr_averages.iloc[4,1] = dnn_post_hr[dnn_post_hr['company'].isin(indices)]['mda'].mean()

dnn_post_hr_averages.iloc[0,2] = dnn_post_hr['hr'].mean()
dnn_post_hr_averages.iloc[1,2] = dnn_post_hr[dnn_post_hr['company'].isin(companies_large)]['hr'].mean()
dnn_post_hr_averages.iloc[2,2] = dnn_post_hr[dnn_post_hr['company'].isin(companies_mid)]['hr'].mean()
dnn_post_hr_averages.iloc[3,2] = dnn_post_hr[dnn_post_hr['company'].isin(companies_small)]['hr'].mean()
dnn_post_hr_averages.iloc[4,2] = dnn_post_hr[dnn_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # GRU

# %%
gru_pre_hr = pd.DataFrame()
gru_pre_mda = pd.DataFrame()
gru_pre_mape = pd.DataFrame()

gru_post_hr = pd.DataFrame()
gru_post_mda = pd.DataFrame()
gru_post_mape = pd.DataFrame()

for i in companies:
    # pre covid
    best = pd.DataFrame(gru_pre[gru_pre['company']==i].sort_values(by='hr').iloc[-1,:]).T

    gru_pre_hr = pd.concat([gru_pre_hr, best])

    best = pd.DataFrame(gru_pre[gru_pre['company']==i].sort_values(by='mda').iloc[-1,:]).T

    gru_pre_mda = pd.concat([gru_pre_mda, best])

    best = pd.DataFrame(gru_pre[gru_pre['company']==i].sort_values(by='mape').iloc[-1,:]).T

    gru_pre_mape = pd.concat([gru_pre_mape, best])


    #post covid
    best = pd.DataFrame(gru_post[gru_post['company']==i].sort_values(by='hr').iloc[-1,:]).T

    gru_post_hr = pd.concat([gru_post_hr, best])

    best = pd.DataFrame(gru_post[gru_post['company']==i].sort_values(by='mda').iloc[-1,:]).T

    gru_post_mda = pd.concat([gru_post_mda, best])

    best = pd.DataFrame(gru_post[gru_post['company']==i].sort_values(by='mape').iloc[-1,:]).T

    gru_post_mape = pd.concat([gru_post_mape, best])

# %%
gru_pre_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_pre_mda_averages.iloc[0,0] = gru_pre_mda['mape'].mean()
gru_pre_mda_averages.iloc[1,0] = gru_pre_mda[gru_pre_mda['company'].isin(companies_large)]['mape'].mean()
gru_pre_mda_averages.iloc[2,0] = gru_pre_mda[gru_pre_mda['company'].isin(companies_mid)]['mape'].mean()
gru_pre_mda_averages.iloc[3,0] = gru_pre_mda[gru_pre_mda['company'].isin(companies_small)]['mape'].mean()
gru_pre_mda_averages.iloc[4,0] = gru_pre_mda[gru_pre_mda['company'].isin(indices)]['mape'].mean()

gru_pre_mda_averages.iloc[0,1] = gru_pre_mda['mda'].mean()
gru_pre_mda_averages.iloc[1,1] = gru_pre_mda[gru_pre_mda['company'].isin(companies_large)]['mda'].mean()
gru_pre_mda_averages.iloc[2,1] = gru_pre_mda[gru_pre_mda['company'].isin(companies_mid)]['mda'].mean()
gru_pre_mda_averages.iloc[3,1] = gru_pre_mda[gru_pre_mda['company'].isin(companies_small)]['mda'].mean()
gru_pre_mda_averages.iloc[4,1] = gru_pre_mda[gru_pre_mda['company'].isin(indices)]['mda'].mean()

gru_pre_mda_averages.iloc[0,2] = gru_pre_mda['hr'].mean()
gru_pre_mda_averages.iloc[1,2] = gru_pre_mda[gru_pre_mda['company'].isin(companies_large)]['hr'].mean()
gru_pre_mda_averages.iloc[2,2] = gru_pre_mda[gru_pre_mda['company'].isin(companies_mid)]['hr'].mean()
gru_pre_mda_averages.iloc[3,2] = gru_pre_mda[gru_pre_mda['company'].isin(companies_small)]['hr'].mean()
gru_pre_mda_averages.iloc[4,2] = gru_pre_mda[gru_pre_mda['company'].isin(indices)]['hr'].mean()





gru_pre_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_pre_mape_averages.iloc[0,0] = gru_pre_mape['mape'].mean()
gru_pre_mape_averages.iloc[1,0] = gru_pre_mape[gru_pre_mape['company'].isin(companies_large)]['mape'].mean()
gru_pre_mape_averages.iloc[2,0] = gru_pre_mape[gru_pre_mape['company'].isin(companies_mid)]['mape'].mean()
gru_pre_mape_averages.iloc[3,0] = gru_pre_mape[gru_pre_mape['company'].isin(companies_small)]['mape'].mean()
gru_pre_mape_averages.iloc[4,0] = gru_pre_mape[gru_pre_mape['company'].isin(indices)]['mape'].mean()

gru_pre_mape_averages.iloc[0,1] = gru_pre_mape['mda'].mean()
gru_pre_mape_averages.iloc[1,1] = gru_pre_mape[gru_pre_mape['company'].isin(companies_large)]['mda'].mean()
gru_pre_mape_averages.iloc[2,1] = gru_pre_mape[gru_pre_mape['company'].isin(companies_mid)]['mda'].mean()
gru_pre_mape_averages.iloc[3,1] = gru_pre_mape[gru_pre_mape['company'].isin(companies_small)]['mda'].mean()
gru_pre_mape_averages.iloc[4,1] = gru_pre_mape[gru_pre_mape['company'].isin(indices)]['mda'].mean()

gru_pre_mape_averages.iloc[0,2] = gru_pre_mape['hr'].mean()
gru_pre_mape_averages.iloc[1,2] = gru_pre_mape[gru_pre_mape['company'].isin(companies_large)]['hr'].mean()
gru_pre_mape_averages.iloc[2,2] = gru_pre_mape[gru_pre_mape['company'].isin(companies_mid)]['hr'].mean()
gru_pre_mape_averages.iloc[3,2] = gru_pre_mape[gru_pre_mape['company'].isin(companies_small)]['hr'].mean()
gru_pre_mape_averages.iloc[4,2] = gru_pre_mape[gru_pre_mape['company'].isin(indices)]['hr'].mean()




gru_pre_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_pre_hr_averages.iloc[0,0] = gru_pre_hr['mape'].mean()
gru_pre_hr_averages.iloc[1,0] = gru_pre_hr[gru_pre_hr['company'].isin(companies_large)]['mape'].mean()
gru_pre_hr_averages.iloc[2,0] = gru_pre_hr[gru_pre_hr['company'].isin(companies_mid)]['mape'].mean()
gru_pre_hr_averages.iloc[3,0] = gru_pre_hr[gru_pre_hr['company'].isin(companies_small)]['mape'].mean()
gru_pre_hr_averages.iloc[4,0] = gru_pre_hr[gru_pre_hr['company'].isin(indices)]['mape'].mean()

gru_pre_hr_averages.iloc[0,1] = gru_pre_hr['mda'].mean()
gru_pre_hr_averages.iloc[1,1] = gru_pre_hr[gru_pre_hr['company'].isin(companies_large)]['mda'].mean()
gru_pre_hr_averages.iloc[2,1] = gru_pre_hr[gru_pre_hr['company'].isin(companies_mid)]['mda'].mean()
gru_pre_hr_averages.iloc[3,1] = gru_pre_hr[gru_pre_hr['company'].isin(companies_small)]['mda'].mean()
gru_pre_hr_averages.iloc[4,1] = gru_pre_hr[gru_pre_hr['company'].isin(indices)]['mda'].mean()

gru_pre_hr_averages.iloc[0,2] = gru_pre_hr['hr'].mean()
gru_pre_hr_averages.iloc[1,2] = gru_pre_hr[gru_pre_hr['company'].isin(companies_large)]['hr'].mean()
gru_pre_hr_averages.iloc[2,2] = gru_pre_hr[gru_pre_hr['company'].isin(companies_mid)]['hr'].mean()
gru_pre_hr_averages.iloc[3,2] = gru_pre_hr[gru_pre_hr['company'].isin(companies_small)]['hr'].mean()
gru_pre_hr_averages.iloc[4,2] = gru_pre_hr[gru_pre_hr['company'].isin(indices)]['hr'].mean()



gru_post_mda_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_post_mda_averages.iloc[0,0] = gru_post_mda['mape'].mean()
gru_post_mda_averages.iloc[1,0] = gru_post_mda[gru_post_mda['company'].isin(companies_large)]['mape'].mean()
gru_post_mda_averages.iloc[2,0] = gru_post_mda[gru_post_mda['company'].isin(companies_mid)]['mape'].mean()
gru_post_mda_averages.iloc[3,0] = gru_post_mda[gru_post_mda['company'].isin(companies_small)]['mape'].mean()
gru_post_mda_averages.iloc[4,0] = gru_post_mda[gru_post_mda['company'].isin(indices)]['mape'].mean()

gru_post_mda_averages.iloc[0,1] = gru_post_mda['mda'].mean()
gru_post_mda_averages.iloc[1,1] = gru_post_mda[gru_post_mda['company'].isin(companies_large)]['mda'].mean()
gru_post_mda_averages.iloc[2,1] = gru_post_mda[gru_post_mda['company'].isin(companies_mid)]['mda'].mean()
gru_post_mda_averages.iloc[3,1] = gru_post_mda[gru_post_mda['company'].isin(companies_small)]['mda'].mean()
gru_post_mda_averages.iloc[4,1] = gru_post_mda[gru_post_mda['company'].isin(indices)]['mda'].mean()

gru_post_mda_averages.iloc[0,2] = gru_post_mda['hr'].mean()
gru_post_mda_averages.iloc[1,2] = gru_post_mda[gru_post_mda['company'].isin(companies_large)]['hr'].mean()
gru_post_mda_averages.iloc[2,2] = gru_post_mda[gru_post_mda['company'].isin(companies_mid)]['hr'].mean()
gru_post_mda_averages.iloc[3,2] = gru_post_mda[gru_post_mda['company'].isin(companies_small)]['hr'].mean()
gru_post_mda_averages.iloc[4,2] = gru_post_mda[gru_post_mda['company'].isin(indices)]['hr'].mean()





gru_post_mape_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_post_mape_averages.iloc[0,0] = gru_post_mape['mape'].mean()
gru_post_mape_averages.iloc[1,0] = gru_post_mape[gru_post_mape['company'].isin(companies_large)]['mape'].mean()
gru_post_mape_averages.iloc[2,0] = gru_post_mape[gru_post_mape['company'].isin(companies_mid)]['mape'].mean()
gru_post_mape_averages.iloc[3,0] = gru_post_mape[gru_post_mape['company'].isin(companies_small)]['mape'].mean()
gru_post_mape_averages.iloc[4,0] = gru_post_mape[gru_post_mape['company'].isin(indices)]['mape'].mean()

gru_post_mape_averages.iloc[0,1] = gru_post_mape['mda'].mean()
gru_post_mape_averages.iloc[1,1] = gru_post_mape[gru_post_mape['company'].isin(companies_large)]['mda'].mean()
gru_post_mape_averages.iloc[2,1] = gru_post_mape[gru_post_mape['company'].isin(companies_mid)]['mda'].mean()
gru_post_mape_averages.iloc[3,1] = gru_post_mape[gru_post_mape['company'].isin(companies_small)]['mda'].mean()
gru_post_mape_averages.iloc[4,1] = gru_post_mape[gru_post_mape['company'].isin(indices)]['mda'].mean()

gru_post_mape_averages.iloc[0,2] = gru_post_mape['hr'].mean()
gru_post_mape_averages.iloc[1,2] = gru_post_mape[gru_post_mape['company'].isin(companies_large)]['hr'].mean()
gru_post_mape_averages.iloc[2,2] = gru_post_mape[gru_post_mape['company'].isin(companies_mid)]['hr'].mean()
gru_post_mape_averages.iloc[3,2] = gru_post_mape[gru_post_mape['company'].isin(companies_small)]['hr'].mean()
gru_post_mape_averages.iloc[4,2] = gru_post_mape[gru_post_mape['company'].isin(indices)]['hr'].mean()




gru_post_hr_averages = pd.DataFrame(columns=['mape', 'mda', 'hr'], index=['all', 'large', 'mid', 'small', 'index'])

gru_post_hr_averages.iloc[0,0] = gru_post_hr['mape'].mean()
gru_post_hr_averages.iloc[1,0] = gru_post_hr[gru_post_hr['company'].isin(companies_large)]['mape'].mean()
gru_post_hr_averages.iloc[2,0] = gru_post_hr[gru_post_hr['company'].isin(companies_mid)]['mape'].mean()
gru_post_hr_averages.iloc[3,0] = gru_post_hr[gru_post_hr['company'].isin(companies_small)]['mape'].mean()
gru_post_hr_averages.iloc[4,0] = gru_post_hr[gru_post_hr['company'].isin(indices)]['mape'].mean()

gru_post_hr_averages.iloc[0,1] = gru_post_hr['mda'].mean()
gru_post_hr_averages.iloc[1,1] = gru_post_hr[gru_post_hr['company'].isin(companies_large)]['mda'].mean()
gru_post_hr_averages.iloc[2,1] = gru_post_hr[gru_post_hr['company'].isin(companies_mid)]['mda'].mean()
gru_post_hr_averages.iloc[3,1] = gru_post_hr[gru_post_hr['company'].isin(companies_small)]['mda'].mean()
gru_post_hr_averages.iloc[4,1] = gru_post_hr[gru_post_hr['company'].isin(indices)]['mda'].mean()

gru_post_hr_averages.iloc[0,2] = gru_post_hr['hr'].mean()
gru_post_hr_averages.iloc[1,2] = gru_post_hr[gru_post_hr['company'].isin(companies_large)]['hr'].mean()
gru_post_hr_averages.iloc[2,2] = gru_post_hr[gru_post_hr['company'].isin(companies_mid)]['hr'].mean()
gru_post_hr_averages.iloc[3,2] = gru_post_hr[gru_post_hr['company'].isin(companies_small)]['hr'].mean()
gru_post_hr_averages.iloc[4,2] = gru_post_hr[gru_post_hr['company'].isin(indices)]['hr'].mean()

# %% [markdown]
# # Tables

# %%
with pd.ExcelWriter('Performance_tables.xlsx', engine='xlsxwriter') as writer:

    ari_pre_mape_averages.to_excel(writer, sheet_name='ari_pre')

    ari_post_mape_averages.to_excel(writer, sheet_name='ari_post')


    proph_pre_mape_averages.to_excel(writer, sheet_name='proph_pre_mape')
    proph_pre_mda_averages.to_excel(writer, sheet_name='proph_pre_mda')
    proph_pre_hr_averages.to_excel(writer, sheet_name='proph_pre_hr')

    proph_post_mape_averages.to_excel(writer, sheet_name='proph_post_mape')
    proph_post_mda_averages.to_excel(writer, sheet_name='proph_post_mda')
    proph_post_hr_averages.to_excel(writer, sheet_name='proph_post_mahr')


    xgb_pre_mape_averages.to_excel(writer, sheet_name='xgb_pre_mape')
    xgb_pre_mda_averages.to_excel(writer, sheet_name='xgb_pre_mda')
    xgb_pre_hr_averages.to_excel(writer, sheet_name='xgb_pre_hr')

    xgb_post_mape_averages.to_excel(writer, sheet_name='xgb_post_mape')
    xgb_post_mda_averages.to_excel(writer, sheet_name='xgb_post_mda')
    xgb_post_hr_averages.to_excel(writer, sheet_name='xgb_post_hr')


    rf_pre_mape_averages.to_excel(writer, sheet_name='rf_pre_mape')
    rf_pre_mda_averages.to_excel(writer, sheet_name='rf_pre_mda')
    rf_pre_hr_averages.to_excel(writer, sheet_name='rf_pre_hr')

    rf_post_mape_averages.to_excel(writer, sheet_name='rf_post_mape')
    rf_post_mda_averages.to_excel(writer, sheet_name='rf_post_mda')
    rf_post_hr_averages.to_excel(writer, sheet_name='rf_post_hr')


    et_pre_mape_averages.to_excel(writer, sheet_name='et_pre_mape')
    et_pre_mda_averages.to_excel(writer, sheet_name='et_pre_mda')
    et_pre_hr_averages.to_excel(writer, sheet_name='et_pre_hr')

    et_post_mape_averages.to_excel(writer, sheet_name='et_post_mape')
    et_post_mda_averages.to_excel(writer, sheet_name='et_post_mda')
    et_post_hr_averages.to_excel(writer, sheet_name='et_post_hr')


    lstm_pre_mape_averages.to_excel(writer, sheet_name='lstm_pre_mape')
    lstm_pre_mda_averages.to_excel(writer, sheet_name='lstm_pre_mda')
    lstm_pre_hr_averages.to_excel(writer, sheet_name='lstm_pre_hr')

    lstm_post_mape_averages.to_excel(writer, sheet_name='lstm_post_mape')
    lstm_post_mda_averages.to_excel(writer, sheet_name='lstm_post_mda')
    lstm_post_hr_averages.to_excel(writer, sheet_name='lstm_post_hr')


    mlp_pre_mape_averages.to_excel(writer, sheet_name='mlp_pre_mape')
    mlp_pre_mda_averages.to_excel(writer, sheet_name='mlp_pre_mda')
    mlp_pre_hr_averages.to_excel(writer, sheet_name='mlp_pre_hr')

    mlp_post_mape_averages.to_excel(writer, sheet_name='mlp_post_mape')
    mlp_post_mda_averages.to_excel(writer, sheet_name='mlp_post_mda')
    mlp_post_hr_averages.to_excel(writer, sheet_name='mlp_post_hr')


    dnn_pre_mape_averages.to_excel(writer, sheet_name='dnn_pre_mape')
    dnn_pre_mda_averages.to_excel(writer, sheet_name='dnn_pre_mda')
    dnn_pre_hr_averages.to_excel(writer, sheet_name='dnn_pre_hr')

    dnn_post_mape_averages.to_excel(writer, sheet_name='dnn_post_mape')
    dnn_post_mda_averages.to_excel(writer, sheet_name='dnn_post_mda')
    dnn_post_hr_averages.to_excel(writer, sheet_name='dnn_post_hr')


    gru_pre_mape_averages.to_excel(writer, sheet_name='gru_pre_mape')
    gru_pre_mda_averages.to_excel(writer, sheet_name='gru_pre_mda')
    gru_pre_hr_averages.to_excel(writer, sheet_name='gru_pre_hr')

    gru_post_mape_averages.to_excel(writer, sheet_name='gru_post_mape')
    gru_post_mda_averages.to_excel(writer, sheet_name='gru_post_mda')
    gru_post_hr_averages.to_excel(writer, sheet_name='gru_post_hr')

# %%
ari_post_hr_averages
# Out:
#            mape       mda         hr
# all    0.015884  0.576118   50.26951
# large  0.017286    0.5288  47.171315
# mid     0.01418    0.6164  50.557769
# small  0.013901    0.5432  51.792829
# index  0.021596     0.676  53.486056

# %%
ari_post_mape_averages
# Out:
#            mape       mda         hr
# all    0.015884  0.576118   50.26951
# large  0.017286    0.5288  47.171315
# mid     0.01418    0.6164  50.557769
# small  0.013901    0.5432  51.792829
# index  0.021596     0.676  53.486056
